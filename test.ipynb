# %%
import pandas as pd
import  matplotlib.pyplot as plt
import numpy as np
import  seaborn as sns

# %%
career_df = pd.read_csv("dist/career.csv")
career_df.head()
# Out:
#                        社員番号 自分の能力を発揮できる仕事上の得意分野が見つかっている\n  \
# 0  -4taxxVbT1nU-J5fHWmDfQ==                  4 そう思う／当てはまる
# 1  -EtuCRccKFQgi3UfXRvRkA==            5 強くそう思う／とても当てはまる
# 2  -JxDfe1I3lMhJDvo7mmvoA==                  4 そう思う／当てはまる
# 3  -Q5JF_Zj03QFrpbCJWPR3A==            5 強くそう思う／とても当てはまる
# 4  -WNGlH_XHI3_niAnslX8gg==                  4 そう思う／当てはまる
#
#   自分はどんな仕事をやりたいのか明らかである      \n 自分は何を望んで今の仕事をしているのかわかっている\n  \
# 0                   3 どちらとも言えない                4 そう思う／当てはまる
# 1            5 強くそう思う／とても当てはまる           5 強くそう思う／とても当てはまる
# 2            5 強くそう思う／とても当てはまる           5 強くそう思う／とても当てはまる
# 3            5 強くそう思う／とても当てはまる           5 強くそう思う／とても当てはまる
# 4        2 あまりそう思わない／あまり当てはまらない                 3 どちらとも言えない
#
#   自分なりの職業的な生き方に関する目標・目的がはっきりしている\n 自分のこれからのキャリアには、あまり関心がない\n  \
# 0                      3 どちらとも言えない              4 そう思う／当てはまる
# 1             1 全くそう思わない／全く当てはまらない      1 全くそう思わない／全く当てはまらない
# 2                     4 そう思う／当てはまる      1 全くそう思わない／全く当てはまらない
# 3               5 強くそう思う／とても当てはまる         5 強くそう思う／とても当てはまる
# 4                      3 どちらとも言えない    2 あまりそう思わない／あまり当てはまらない
#
#   これからのキャリアを、より充実したものにしたいと強く思う\n キャリア設計（職業生活の設計）は、自分にとって重要な課題である\n  \
# 0                   4 そう思う／当てはまる                      4 そう思う／当てはまる
# 1             5 強くそう思う／とても当てはまる                 5 強くそう思う／とても当てはまる
# 2             5 強くそう思う／とても当てはまる                       4 そう思う／当てはまる
# 3             5 強くそう思う／とても当てはまる                       4 そう思う／当てはまる
# 4                   4 そう思う／当てはまる                      4 そう思う／当てはまる
#
#   これからのキャリアをどう歩むべきか、あまり考えていない\n 納得いくキャリアを歩めるかどうかは、自分の責任だと思う\n  ...  \
# 0                   3 どちらとも言えない                  4 そう思う／当てはまる  ...
# 1          1 全くそう思わない／全く当てはまらない            5 強くそう思う／とても当てはまる   ...
# 2          1 全くそう思わない／全く当てはまらない                  4 そう思う／当てはまる  ...
# 3          1 全くそう思わない／全く当てはまらない            5 強くそう思う／とても当てはまる   ...
# 4        2 あまりそう思わない／あまり当てはまらない            5 強くそう思う／とても当てはまる   ...
#
#   自分の進捗をモニタリングし計画を柔軟に調整できる フィードバックを受けて自ら仕事を改善できる  \
# 0             4 そう思う／当てはまる     5 強くそう思う／とても当てはまる
# 1        5 強くそう思う／とても当てはまる     5 強くそう思う／とても当てはまる
# 2             4 そう思う／当てはまる          4 そう思う／当てはまる
# 3   2 あまりそう思わない／あまり当てはまらない     5 強くそう思う／とても当てはまる
# 4             4 そう思う／当てはまる          4 そう思う／当てはまる
#
#   業務データを可視化し BI ダッシュボードで意思決定に活用できる RPA／ノーコードツールで反復的な業務フローを自動化できる  \
# 0                      3 どちらとも言えない        2 あまりそう思わない／あまり当てはまらない
# 1                5 強くそう思う／とても当てはまる             5 強くそう思う／とても当てはまる
# 2                     4 そう思う／当てはまる                   3 どちらとも言えない
# 3                5 強くそう思う／とても当てはまる             5 強くそう思う／とても当てはまる
# 4           2 あまりそう思わない／あまり当てはまらない        2 あまりそう思わない／あまり当てはまらない
#
#   生成 AI や機械学習モデルを業務改善に活用できる クラウド環境のアクセス権限を監査し情報保護を徹底できる  \
# 0               3 どちらとも言えない                 3 どちらとも言えない
# 1         5 強くそう思う／とても当てはまる           5 強くそう思う／とても当てはまる
# 2              4 そう思う／当てはまる      2 あまりそう思わない／あまり当てはまらない
# 3         5 強くそう思う／とても当てはまる      2 あまりそう思わない／あまり当てはまらない
# 4               3 どちらとも言えない      2 あまりそう思わない／あまり当てはまらない
#
#   デジタルマーケティング施策（SNS 広告等）をデータで最適化できる 顧客・市場データを用いて新商品・サービス企画を立案できる  \
# 0            2 あまりそう思わない／あまり当てはまらない       2 あまりそう思わない／あまり当てはまらない
# 1                 5 強くそう思う／とても当てはまる            5 強くそう思う／とても当てはまる
# 2                 5 強くそう思う／とても当てはまる                 4 そう思う／当てはまる
# 3                       3 どちらとも言えない            5 強くそう思う／とても当てはまる
# 4            2 あまりそう思わない／あまり当てはまらない                 4 そう思う／当てはまる
#
#   クラウド／DevOps 環境を構築し IaC で継続的デプロイを管理できる  \
# 0                2 あまりそう思わない／あまり当てはまらない
# 1                     5 強くそう思う／とても当てはまる
# 2                2 あまりそう思わない／あまり当てはまらない
# 3                           3 どちらとも言えない
# 4                          4 そう思う／当てはまる
#
#   デジタルツインや IoT データを用いたサプライチェーン最適化を提案・実装できる
# 0                   2 あまりそう思わない／あまり当てはまらない
# 1                     1 全くそう思わない／全く当てはまらない
# 2                   2 あまりそう思わない／あまり当てはまらない
# 3                   2 あまりそう思わない／あまり当てはまらない
# 4                   2 あまりそう思わない／あまり当てはまらない
#
# [5 rows x 46 columns]

# %%
dx_df = pd.read_csv("dist/dx.csv")
dx_df.head()
# Out:
#                        社員番号                研修実施日      研修カテゴリ  \
# 0  -2Sq3E0WkZj8pL7jxdL3Cg==  2024-04-15 00:00:00  リテラシー_DX基礎
# 1  -2Sq3E0WkZj8pL7jxdL3Cg==  2024-04-16 00:00:00  リテラシー_DX基礎
# 2  -5W_JQCSTAYe2gGJMuT4_w==  2023-04-20 00:00:00  リテラシー_DX基礎
# 3  -5W_JQCSTAYe2gGJMuT4_w==  2023-04-20 00:00:00  リテラシー_DX基礎
# 4  -5W_JQCSTAYe2gGJMuT4_w==  2024-04-15 00:00:00  リテラシー_DX基礎
#
#                  研修名
# 0       【DX基礎研修】DX概論
# 1    【DX基礎研修】ものづくり概論
# 2      【DX基礎研修】社内事例①
# 3      【DX基礎研修】社内事例②
# 4  【DX基礎研修】イントロダクション

# %%
hr_df = pd.read_csv("dist/hr.csv")
hr_df.head()
# Out:
#                        社員番号          カテゴリ       研修名                    実施日
# 0  -4taxxVbT1nU-J5fHWmDfQ==      3等級昇格者研修  3等級昇格者研修    2023-06-02 00:00:00
# 1  -4taxxVbT1nU-J5fHWmDfQ==  ビジネススキルアップ研修   マーケティング  2022/11/15,2022/11/29
# 2  -4taxxVbT1nU-J5fHWmDfQ==  ビジネススキルアップ研修   マーケティング  2022/11/15,2022/11/29
# 3  -4taxxVbT1nU-J5fHWmDfQ==  ビジネススキルアップ研修   マーケティング  2022/11/15,2022/11/29
# 4  -4taxxVbT1nU-J5fHWmDfQ==  ビジネススキルアップ研修   マーケティング  2022/11/15,2022/11/29

# %%
overtime_df = pd.read_csv("dist/overtime_work_by_month.csv")
overtime_df.head()
# Out:
#                        社員番号        date  hours
# 0  -1sqs0GXzpPJuAVKHUUFgg==  2022-01-01   10.0
# 1  -1sqs0GXzpPJuAVKHUUFgg==  2022-02-01   11.0
# 2  -1sqs0GXzpPJuAVKHUUFgg==  2022-03-01   18.0
# 3  -1sqs0GXzpPJuAVKHUUFgg==  2022-04-01   30.0
# 4  -1sqs0GXzpPJuAVKHUUFgg==  2022-05-01   27.0

# %%
position_df = pd.read_csv("dist/position_history.csv")
position_df.head()
# Out:
#                        社員番号  year 勤務区分        役職
# 0  -1sqs0GXzpPJuAVKHUUFgg==    22  正社員        一般
# 1  -1sqs0GXzpPJuAVKHUUFgg==    23  正社員        一般
# 2  -1sqs0GXzpPJuAVKHUUFgg==    24  正社員  グループリーダー
# 3  -2Sq3E0WkZj8pL7jxdL3Cg==    23  正社員        一般
# 4  -2Sq3E0WkZj8pL7jxdL3Cg==    24  正社員        一般

# %%
udemy_df = pd.read_csv("dist/udemy_activity.csv")
udemy_df.head()
# Out:
#                        社員番号    コースID    コースタイトル レクチャーもしくはクイズ  レクチャー/クイズID  \
# 0  -1sqs0GXzpPJuAVKHUUFgg==  4615016  企業オリジナル講座         Quiz      5528090
# 1  -1sqs0GXzpPJuAVKHUUFgg==  4615016  企業オリジナル講座         Quiz      5528090
# 2  -1sqs0GXzpPJuAVKHUUFgg==  4615016  企業オリジナル講座         Quiz      5528100
# 3  -1sqs0GXzpPJuAVKHUUFgg==  4615016  企業オリジナル講座         Quiz      5528100
# 4  -1sqs0GXzpPJuAVKHUUFgg==  4615016  企業オリジナル講座         Quiz      5528102
#
#   レクチャー/クイズの題名              開始日              終了日  推定完了率%  最終結果（クイズの場合）  \
# 0    企業オリジナル講座  2022/4/11 10:10  2022/4/11 10:10   100.0           0.0
# 1    企業オリジナル講座  2022/4/11 10:11  2022/4/11 10:11   100.0         100.0
# 2    企業オリジナル講座  2022/4/11 10:26  2022/4/11 10:26   100.0           0.0
# 3    企業オリジナル講座  2022/4/11 10:27  2022/4/11 10:27   100.0         100.0
# 4    企業オリジナル講座  2022/4/11 10:21  2022/4/11 10:21   100.0         100.0
#
#    マーク済み修了   コースカテゴリー
# 0     True  企業オリジナル講座
# 1     True  企業オリジナル講座
# 2     True  企業オリジナル講座
# 3     True  企業オリジナル講座
# 4     True  企業オリジナル講座

# %%
train_df = pd.read_csv("dist/train.csv")
train_df.head()
# Out:
#                        社員番号               category  target
# 0  -2Sq3E0WkZj8pL7jxdL3Cg==        コンテンツ・サービス・デザイン       0
# 1  -2Sq3E0WkZj8pL7jxdL3Cg==  コーポレート管理部門/技術・データ・BPR       0
# 2  -2Sq3E0WkZj8pL7jxdL3Cg==            プロダクトマネジメント       0
# 3  -2Sq3E0WkZj8pL7jxdL3Cg==                マーケティング       0
# 4  -2Sq3E0WkZj8pL7jxdL3Cg==             事業企画・開発・研究       0

# %%
test_df = pd.read_csv("dist/test.csv")
test_df.head()
# Out:
#                        社員番号               category
# 0  -1sqs0GXzpPJuAVKHUUFgg==        コンテンツ・サービス・デザイン
# 1  -1sqs0GXzpPJuAVKHUUFgg==  コーポレート管理部門/技術・データ・BPR
# 2  -1sqs0GXzpPJuAVKHUUFgg==            プロダクトマネジメント
# 3  -1sqs0GXzpPJuAVKHUUFgg==                マーケティング
# 4  -1sqs0GXzpPJuAVKHUUFgg==             事業企画・開発・研究

# %%
sample_df = pd.read_csv("dist/sample_submission.csv")
sample_df.head()
# Out:
#      target
# 0  0.559836
# 1  0.064199
# 2  0.026592
# 3  0.576083
# 4  0.542395

# %% [markdown]
# ### Train

# %%
for col in train_df.columns:
    print("unique: ", len(train_df[col].unique()))
    print(train_df[col].value_counts())
# Out:
# unique:  1223
# 社員番号
# -2Sq3E0WkZj8pL7jxdL3Cg==    6
# -4taxxVbT1nU-J5fHWmDfQ==    6
# -6LqZqVuZIYsbdzQPYGopw==    6
# -EtuCRccKFQgi3UfXRvRkA==    6
# -J_LZatYK7_1pM_11ZOAyw==    6
#                            ..
# zk6PHZ_EI_YvJqRx4VBq9g==    6
# zl0ymPRO2UXnDz5D88UbuQ==    6
# znM2OAu2K1EoZZdRnhYRCw==    6
# zs-xCihHPKBivyOIXncfzQ==    6
# zuplFpzBoM4c1dFy5HPXqg==    6
# Name: count, Length: 1223, dtype: int64
# unique:  6
# category
# コンテンツ・サービス・デザイン          1223
# コーポレート管理部門/技術・データ・BPR    1223
# プロダクトマネジメント              1223
# マーケティング                  1223
# 事業企画・開発・研究               1223
# 営業                       1223
# Name: count, dtype: int64
# unique:  2
# target
# 0    7049
# 1     289
# Name: count, dtype: int64

# %%
counts = train_df['target'].value_counts().sort_index()
print(counts)
# Out:
# target
# 0    7049
# 1     289
# Name: count, dtype: int64

# %%
counts.plot.bar(rot=0, color=['skyblue', 'orange'])
plt.title('Counts of 0 and 1 in flag column')
plt.xlabel('Value')
plt.ylabel('Count')
plt.xticks([0, 1], ['0', '1'])  # x軸ラベル明示（任意）
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Test

# %%
for col in test_df.columns:
    print("unique: ", len(test_df[col].unique()))
    print(test_df[col].value_counts())å
# Out:
# unique:  1837
# 社員番号
# -1sqs0GXzpPJuAVKHUUFgg==    6
# -4jh26kLzkU8JFQwdeQU9w==    6
# -5W_JQCSTAYe2gGJMuT4_w==    6
# -AUHIuzsGtdhhsPuX6dGLw==    6
# -DyuCGlo_yVK2ddwpxupSA==    6
#                            ..
# zsZqwglfVER5ZvrJ2UWwRw==    6
# zwcjIiu_sqUs8akLOfuYKA==    6
# zxPKKLM85QljzRfp0yisow==    6
# zxY0Eflwm1tYj1Wt6vo_1g==    6
# zxmtr2h4ypvsNq02K9AMJg==    6
# Name: count, Length: 1837, dtype: int64
# unique:  6
# category
# コンテンツ・サービス・デザイン          1837
# コーポレート管理部門/技術・データ・BPR    1837
# プロダクトマネジメント              1837
# マーケティング                  1837
# 事業企画・開発・研究               1837
# 営業                       1837
# Name: count, dtype: int64

# %% [markdown]
# ### Position

# %%
for col in position_df.columns:
    print("unique: ", len(position_df[col].unique()))
    print(position_df[col].value_counts())
# Out:
# unique:  3060
# 社員番号
# zxmtr2h4ypvsNq02K9AMJg==    3
# -1sqs0GXzpPJuAVKHUUFgg==    3
# zxY0Eflwm1tYj1Wt6vo_1g==    3
# zY-6s0Il-DvT5NfGMQ86Vw==    3
# zXH8l0Wd5_sbgEGivs62_g==    3
#                            ..
# nSvUNPkIJgNc4u5Q0e9C6g==    2
# nLxabi7P5ziIhu98VTPYOQ==    2
# nHIEBDdHtTpL8So0iumyYA==    2
# nGJkbozdUeaNkz8B3REZdw==    2
# nrd5Pe6kAzjnLd6MTrz6uw==    2
# Name: count, Length: 3060, dtype: int64
# unique:  3
# year
# 24    3060
# 23    3051
# 22    2485
# Name: count, dtype: int64
# unique:  2
# 勤務区分
# 正社員         7251
# 正社員(管理職)    1345
# Name: count, dtype: int64
# unique:  10
# 役職
# 一般          6653
# グループリーダー     897
# 課長           686
# 部長           181
# 副部長           66
# 副本部長          34
# 室長            32
# 本部長           29
# 支社長           13
# 副室長            5
# Name: count, dtype: int64

# %% [markdown]
# ### Overtime

# %%
for col in overtime_df.columns:
    print("unique: ", len(overtime_df[col].unique()))
    print(overtime_df[col].value_counts())
# Out:
# unique:  3060
# 社員番号
# zxmtr2h4ypvsNq02K9AMJg==    36
# -1sqs0GXzpPJuAVKHUUFgg==    36
# zxY0Eflwm1tYj1Wt6vo_1g==    36
# zY-6s0Il-DvT5NfGMQ86Vw==    36
# zXH8l0Wd5_sbgEGivs62_g==    36
#                             ..
# i0fR6uoRAvbrNA5gPg5h2Q==    15
# 4OgSQfI5hdgAj_dEDV5DGQ==    15
# ppsqClNZ920rrDPBA5s6HQ==    15
# WO4aEWwn7LhluiokTCysxA==    15
# o7uCE80LqHLVtdcGqD4ypQ==    15
# Name: count, Length: 3060, dtype: int64
# unique:  36
# date
# 2024-12-01    3060
# 2024-11-01    3059
# 2024-09-01    3059
# 2024-10-01    3059
# 2024-05-01    3058
# 2024-06-01    3058
# 2024-01-01    3058
# 2024-04-01    3058
# 2024-08-01    3058
# 2024-07-01    3058
# 2024-02-01    3056
# 2024-03-01    3055
# 2023-02-01    3050
# 2023-03-01    3050
# 2023-01-01    3050
# 2023-12-01    3037
# 2023-11-01    3031
# 2023-10-01    3023
# 2023-08-01    3004
# 2023-09-01    3004
# 2023-07-01    2970
# 2023-06-01    2913
# 2023-05-01    2905
# 2023-04-01    2869
# 2022-03-01    2473
# 2022-02-01    2461
# 2022-01-01    2447
# 2022-12-01    2446
# 2022-11-01    2426
# 2022-10-01    2414
# 2022-09-01    2398
# 2022-08-01    2385
# 2022-07-01    2368
# 2022-06-01    2353
# 2022-05-01    2339
# 2022-04-01    2327
# Name: count, dtype: int64
# unique:  175
# hours
# 0.0      7375
# 65.0     2776
# 40.0     1927
# 35.0     1860
# 50.0     1841
#          ...
# 162.0       1
# 181.0       1
# 172.0       1
# 151.0       1
# 156.0       1
# Name: count, Length: 175, dtype: int64

# %%
overtime_df["date"] = pd.to_datetime()
# Out:
# dtype('O')

# %% [markdown]
# ### Carrer

# %%
for col in career_df.columns:
    print("unique: ", len(career_df[col].unique()))
    print(career_df[col].value_counts())
# Out:
# unique:  375
# 社員番号
# -4taxxVbT1nU-J5fHWmDfQ==    1
# -EtuCRccKFQgi3UfXRvRkA==    1
# -JxDfe1I3lMhJDvo7mmvoA==    1
# -Q5JF_Zj03QFrpbCJWPR3A==    1
# -WNGlH_XHI3_niAnslX8gg==    1
#                            ..
# zE-QpDZK8OhMqhzaomUhoA==    1
# zcgSr41mcUYA1C0jH4cxVQ==    1
# zow_7-qpjek7cWzX4-70fg==    1
# zs-xCihHPKBivyOIXncfzQ==    1
# zsZqwglfVER5ZvrJ2UWwRw==    1
# Name: count, Length: 375, dtype: int64
# unique:  5
# 自分の能力を発揮できる仕事上の得意分野が見つかっている\n
# 4 そう思う／当てはまる              233
# 3 どちらとも言えない                77
# 5 強くそう思う／とても当てはまる          38
# 2 あまりそう思わない／あまり当てはまらない     25
# 1 全くそう思わない／全く当てはまらない        2
# Name: count, dtype: int64
# unique:  5
# 自分はどんな仕事をやりたいのか明らかである      \n
# 4 そう思う／当てはまる              212
# 3 どちらとも言えない                83
# 5 強くそう思う／とても当てはまる          44
# 2 あまりそう思わない／あまり当てはまらない     33
# 1 全くそう思わない／全く当てはまらない        3
# Name: count, dtype: int64
# unique:  5
# 自分は何を望んで今の仕事をしているのかわかっている\n
# 4 そう思う／当てはまる              222
# 3 どちらとも言えない                64
# 5 強くそう思う／とても当てはまる          58
# 2 あまりそう思わない／あまり当てはまらない     26
# 1 全くそう思わない／全く当てはまらない        5
# Name: count, dtype: int64
# unique:  5
# 自分なりの職業的な生き方に関する目標・目的がはっきりしている\n
# 4 そう思う／当てはまる              188
# 3 どちらとも言えない                98
# 5 強くそう思う／とても当てはまる          44
# 2 あまりそう思わない／あまり当てはまらない     36
# 1 全くそう思わない／全く当てはまらない        9
# Name: count, dtype: int64
# unique:  5
# 自分のこれからのキャリアには、あまり関心がない\n
# 2 あまりそう思わない／あまり当てはまらない    150
# 1 全くそう思わない／全く当てはまらない      140
# 3 どちらとも言えない                53
# 4 そう思う／当てはまる               25
# 5 強くそう思う／とても当てはまる           7
# Name: count, dtype: int64
# unique:  5
# これからのキャリアを、より充実したものにしたいと強く思う\n
# 5 強くそう思う／とても当てはまる         174
# 4 そう思う／当てはまる              157
# 3 どちらとも言えない                35
# 2 あまりそう思わない／あまり当てはまらない      7
# 1 全くそう思わない／全く当てはまらない        2
# Name: count, dtype: int64
# unique:  5
# キャリア設計（職業生活の設計）は、自分にとって重要な課題である\n
# 4 そう思う／当てはまる              181
# 5 強くそう思う／とても当てはまる         132
# 3 どちらとも言えない                47
# 2 あまりそう思わない／あまり当てはまらない     13
# 1 全くそう思わない／全く当てはまらない        2
# Name: count, dtype: int64
# unique:  5
# これからのキャリアをどう歩むべきか、あまり考えていない\n
# 2 あまりそう思わない／あまり当てはまらない    153
# 1 全くそう思わない／全く当てはまらない       97
# 3 どちらとも言えない                76
# 4 そう思う／当てはまる               42
# 5 強くそう思う／とても当てはまる           7
# Name: count, dtype: int64
# unique:  5
# 納得いくキャリアを歩めるかどうかは、自分の責任だと思う\n
# 4 そう思う／当てはまる              186
# 5 強くそう思う／とても当てはまる         112
# 3 どちらとも言えない                62
# 2 あまりそう思わない／あまり当てはまらない     12
# 1 全くそう思わない／全く当てはまらない        3
# Name: count, dtype: int64
# unique:  5
# キャリア形成は、自分自身の責任である\n
# 4 そう思う／当てはまる              196
# 5 強くそう思う／とても当てはまる         110
# 3 どちらとも言えない                57
# 2 あまりそう思わない／あまり当てはまらない      9
# 1 全くそう思わない／全く当てはまらない        3
# Name: count, dtype: int64
# unique:  5
# 納得いくキャリアを歩めない原因の大半は周囲の環境にある\n
# 2 あまりそう思わない／あまり当てはまらない    172
# 3 どちらとも言えない               133
# 1 全くそう思わない／全く当てはまらない       39
# 4 そう思う／当てはまる               27
# 5 強くそう思う／とても当てはまる           4
# Name: count, dtype: int64
# unique:  5
# キャリアは周りの環境によって決められていくものだと思う\n
# 3 どちらとも言えない               155
# 2 あまりそう思わない／あまり当てはまらない    110
# 4 そう思う／当てはまる               73
# 1 全くそう思わない／全く当てはまらない       30
# 5 強くそう思う／とても当てはまる           7
# Name: count, dtype: int64
# unique:  5
# 新しい環境や状況にも、わりあい早くなじんで対応している
# 4 そう思う／当てはまる              220
# 5 強くそう思う／とても当てはまる          63
# 3 どちらとも言えない                60
# 2 あまりそう思わない／あまり当てはまらない     30
# 1 全くそう思わない／全く当てはまらない        2
# Name: count, dtype: int64
# unique:  5
# 職場環境の変化に対して自分なりに考えて対応している
# 4 そう思う／当てはまる              277
# 5 強くそう思う／とても当てはまる          63
# 3 どちらとも言えない                25
# 2 あまりそう思わない／あまり当てはまらない      9
# 1 全くそう思わない／全く当てはまらない        1
# Name: count, dtype: int64
# unique:  5
# 新しい職場に移ってもすぐに自分らしさを発揮している
# 4 そう思う／当てはまる              185
# 3 どちらとも言えない               110
# 5 強くそう思う／とても当てはまる          41
# 2 あまりそう思わない／あまり当てはまらない     34
# 1 全くそう思わない／全く当てはまらない        5
# Name: count, dtype: int64
# unique:  5
# 職場の制度や仕事が変わってもすぐ対応している
# 4 そう思う／当てはまる              245
# 3 どちらとも言えない                74
# 5 強くそう思う／とても当てはまる          33
# 2 あまりそう思わない／あまり当てはまらない     20
# 1 全くそう思わない／全く当てはまらない        3
# Name: count, dtype: int64
# unique:  5
# 自分の職種・業界分野における最新動向を常に情報収集している
# 4 そう思う／当てはまる              160
# 3 どちらとも言えない               110
# 2 あまりそう思わない／あまり当てはまらない     68
# 5 強くそう思う／とても当てはまる          31
# 1 全くそう思わない／全く当てはまらない        6
# Name: count, dtype: int64
# unique:  5
# 仕事のために新しいことをいろいろ勉強している
# 4 そう思う／当てはまる              195
# 3 どちらとも言えない                91
# 2 あまりそう思わない／あまり当てはまらない     48
# 5 強くそう思う／とても当てはまる          36
# 1 全くそう思わない／全く当てはまらない        5
# Name: count, dtype: int64
# unique:  5
# 社会・経済の動きや成り行きに関する情報を、積極的に収集している
# 4 そう思う／当てはまる              170
# 3 どちらとも言えない                98
# 2 あまりそう思わない／あまり当てはまらない     64
# 5 強くそう思う／とても当てはまる          34
# 1 全くそう思わない／全く当てはまらない        9
# Name: count, dtype: int64
# unique:  5
# 新しい知識・技術を積極的に学ぶように努めている
# 4 そう思う／当てはまる              204
# 3 どちらとも言えない               101
# 2 あまりそう思わない／あまり当てはまらない     35
# 5 強くそう思う／とても当てはまる          33
# 1 全くそう思わない／全く当てはまらない        2
# Name: count, dtype: int64
# unique:  5
# 新しい人間関係が構築できるように、社内外の活動に積極的に参加している
# 2 あまりそう思わない／あまり当てはまらない    120
# 3 どちらとも言えない               107
# 4 そう思う／当てはまる               81
# 1 全くそう思わない／全く当てはまらない       41
# 5 強くそう思う／とても当てはまる          26
# Name: count, dtype: int64
# unique:  5
# 仕事と直接関係ない人とも積極的に交流するようにしている
# 4 そう思う／当てはまる              125
# 2 あまりそう思わない／あまり当てはまらない     97
# 3 どちらとも言えない                84
# 5 強くそう思う／とても当てはまる          41
# 1 全くそう思わない／全く当てはまらない       28
# Name: count, dtype: int64
# unique:  5
# 新しいネットワークづくりに常に取り組んでいる
# 3 どちらとも言えない               128
# 2 あまりそう思わない／あまり当てはまらない    118
# 4 そう思う／当てはまる               67
# 1 全くそう思わない／全く当てはまらない       41
# 5 強くそう思う／とても当てはまる          21
# Name: count, dtype: int64
# unique:  5
# 自分の満足感を高めるように、仕事のやり方を工夫している
# 4 そう思う／当てはまる              245
# 3 どちらとも言えない                66
# 5 強くそう思う／とても当てはまる          41
# 2 あまりそう思わない／あまり当てはまらない     18
# 1 全くそう思わない／全く当てはまらない        5
# Name: count, dtype: int64
# unique:  5
# 常に自発的に仕事を行っている
# 4 そう思う／当てはまる              215
# 3 どちらとも言えない                82
# 5 強くそう思う／とても当てはまる          62
# 2 あまりそう思わない／あまり当てはまらない     14
# 1 全くそう思わない／全く当てはまらない        2
# Name: count, dtype: int64
# unique:  5
# 自分の価値観やポリシーを持って仕事に取り組んでいる
# 4 そう思う／当てはまる              249
# 5 強くそう思う／とても当てはまる          77
# 3 どちらとも言えない                35
# 2 あまりそう思わない／あまり当てはまらない     12
# 1 全くそう思わない／全く当てはまらない        2
# Name: count, dtype: int64
# unique:  5
# 仕事の進め方や企画を立てる上で、今までの延長上のやり方ではなく、自分なりの発想を持って取り組んでいる
# 4 そう思う／当てはまる              237
# 3 どちらとも言えない                74
# 5 強くそう思う／とても当てはまる          49
# 2 あまりそう思わない／あまり当てはまらない     13
# 1 全くそう思わない／全く当てはまらない        2
# Name: count, dtype: int64
# unique:  5
# 少人数チームで協力してタスクを完遂できる
# 4 そう思う／当てはまる              274
# 5 強くそう思う／とても当てはまる          71
# 3 どちらとも言えない                23
# 2 あまりそう思わない／あまり当てはまらない      5
# 1 全くそう思わない／全く当てはまらない        2
# Name: count, dtype: int64
# unique:  5
# メンバー全員のアイデアを取り入れて成果物を作れる
# 4 そう思う／当てはまる              235
# 3 どちらとも言えない                76
# 5 強くそう思う／とても当てはまる          37
# 2 あまりそう思わない／あまり当てはまらない     24
# 1 全くそう思わない／全く当てはまらない        3
# Name: count, dtype: int64
# unique:  5
# 同僚や上司に向けて口頭でプレゼンテーションができる
# 4 そう思う／当てはまる              242
# 5 強くそう思う／とても当てはまる          60
# 3 どちらとも言えない                44
# 2 あまりそう思わない／あまり当てはまらない     26
# 1 全くそう思わない／全く当てはまらない        3
# Name: count, dtype: int64
# unique:  5
# スライドや動画などのデジタル資料を用いて情報を共有できる
# 4 そう思う／当てはまる              249
# 5 強くそう思う／とても当てはまる          65
# 3 どちらとも言えない                43
# 2 あまりそう思わない／あまり当てはまらない     16
# 1 全くそう思わない／全く当てはまらない        2
# Name: count, dtype: int64
# unique:  5
# 異なる視点を比較して最適な解決策を選べる
# 4 そう思う／当てはまる              264
# 3 どちらとも言えない                66
# 5 強くそう思う／とても当てはまる          34
# 2 あまりそう思わない／あまり当てはまらない     10
# 1 全くそう思わない／全く当てはまらない        1
# Name: count, dtype: int64
# unique:  5
# 正解が一つでない問題に対して解決策を導き出せる
# 4 そう思う／当てはまる              242
# 3 どちらとも言えない                78
# 5 強くそう思う／とても当てはまる          40
# 2 あまりそう思わない／あまり当てはまらない     11
# 1 全くそう思わない／全く当てはまらない        4
# Name: count, dtype: int64
# unique:  5
# 複数のアイデアを試行し改善を重ねられる
# 4 そう思う／当てはまる              267
# 3 どちらとも言えない                57
# 5 強くそう思う／とても当てはまる          40
# 2 あまりそう思わない／あまり当てはまらない     10
# 1 全くそう思わない／全く当てはまらない        1
# Name: count, dtype: int64
# unique:  5
# 困難な業務課題に対して独自の解決策を考案できる
# 4 そう思う／当てはまる              226
# 3 どちらとも言えない                95
# 5 強くそう思う／とても当てはまる          33
# 2 あまりそう思わない／あまり当てはまらない     17
# 1 全くそう思わない／全く当てはまらない        4
# Name: count, dtype: int64
# unique:  5
# 自分の進捗をモニタリングし計画を柔軟に調整できる
# 4 そう思う／当てはまる              233
# 3 どちらとも言えない                70
# 5 強くそう思う／とても当てはまる          36
# 2 あまりそう思わない／あまり当てはまらない     33
# 1 全くそう思わない／全く当てはまらない        3
# Name: count, dtype: int64
# unique:  5
# フィードバックを受けて自ら仕事を改善できる
# 4 そう思う／当てはまる              281
# 5 強くそう思う／とても当てはまる          51
# 3 どちらとも言えない                37
# 2 あまりそう思わない／あまり当てはまらない      5
# 1 全くそう思わない／全く当てはまらない        1
# Name: count, dtype: int64
# unique:  5
# 業務データを可視化し BI ダッシュボードで意思決定に活用できる
# 2 あまりそう思わない／あまり当てはまらない    120
# 3 どちらとも言えない               105
# 4 そう思う／当てはまる               80
# 1 全くそう思わない／全く当てはまらない       53
# 5 強くそう思う／とても当てはまる          17
# Name: count, dtype: int64
# unique:  5
# RPA／ノーコードツールで反復的な業務フローを自動化できる
# 2 あまりそう思わない／あまり当てはまらない    112
# 1 全くそう思わない／全く当てはまらない       95
# 4 そう思う／当てはまる               85
# 3 どちらとも言えない                73
# 5 強くそう思う／とても当てはまる          10
# Name: count, dtype: int64
# unique:  5
# 生成 AI や機械学習モデルを業務改善に活用できる
# 4 そう思う／当てはまる              162
# 3 どちらとも言えない                93
# 2 あまりそう思わない／あまり当てはまらない     60
# 5 強くそう思う／とても当てはまる          34
# 1 全くそう思わない／全く当てはまらない       26
# Name: count, dtype: int64
# unique:  5
# クラウド環境のアクセス権限を監査し情報保護を徹底できる
# 2 あまりそう思わない／あまり当てはまらない    102
# 3 どちらとも言えない                98
# 4 そう思う／当てはまる               86
# 1 全くそう思わない／全く当てはまらない       81
# 5 強くそう思う／とても当てはまる           8
# Name: count, dtype: int64
# unique:  5
# デジタルマーケティング施策（SNS 広告等）をデータで最適化できる
# 1 全くそう思わない／全く当てはまらない      128
# 2 あまりそう思わない／あまり当てはまらない    107
# 3 どちらとも言えない                83
# 4 そう思う／当てはまる               41
# 5 強くそう思う／とても当てはまる          16
# Name: count, dtype: int64
# unique:  5
# 顧客・市場データを用いて新商品・サービス企画を立案できる
# 4 そう思う／当てはまる              115
# 2 あまりそう思わない／あまり当てはまらない     93
# 3 どちらとも言えない                81
# 1 全くそう思わない／全く当てはまらない       61
# 5 強くそう思う／とても当てはまる          25
# Name: count, dtype: int64
# unique:  5
# クラウド／DevOps 環境を構築し IaC で継続的デプロイを管理できる
# 1 全くそう思わない／全く当てはまらない      182
# 2 あまりそう思わない／あまり当てはまらない    105
# 3 どちらとも言えない                52
# 4 そう思う／当てはまる               27
# 5 強くそう思う／とても当てはまる           9
# Name: count, dtype: int64
# unique:  5
# デジタルツインや IoT データを用いたサプライチェーン最適化を提案・実装できる
# 1 全くそう思わない／全く当てはまらない      183
# 2 あまりそう思わない／あまり当てはまらない    113
# 3 どちらとも言えない                59
# 4 そう思う／当てはまる               15
# 5 強くそう思う／とても当てはまる           5
# Name: count, dtype: int64

# %% [markdown]
# ### dx_df

# %%
for col in dx_df.columns:
    print("unique: ", len(dx_df[col].unique()))
    print(dx_df[col].value_counts())
# Out:
# unique:  1468
# 社員番号
# pxJxAVJh9De4pduKjrPUlA==    34
# JPHlmkJ2Js9pjbhC3T5Zyg==    32
# v7I0WTFJia3fPucvydp-1Q==    24
# pSWVgRhms4j-D04hspAm3A==    24
# dMXA6lg5PO2_SHuXAmaaUA==    24
#                             ..
# 0cQ8lKZfH1sfS6peQtW7Ug==     1
# 0Su6Ey_toLWK8jVFQiVhGg==     1
# 0P_NOdwbvoIFnTzUi1mX5A==     1
# 0I2ETStnyN4dfgIlbmzJGw==     1
# QeiZWZCI-EbLMyS1NHHjKA==     1
# Name: count, Length: 1468, dtype: int64
# unique:  86
# 研修実施日
# 2023-04-17 00:00:00    1084
# 2023-04-20 00:00:00     599
# 2023-04-19 00:00:00     585
# 2023-04-18 00:00:00     558
# 2023-01-26 00:00:00     333
#                        ...
# 2024-09-13 00:00:00       7
# 2023-09-12 00:00:00       5
# 2024-08-27 00:00:00       3
# 2024-05-28 00:00:00       2
# 2022-04-18 00:00:00       1
# Name: count, Length: 86, dtype: int64
# unique:  10
# 研修カテゴリ
# リテラシー_DX基礎        4252
# DX講演会             1301
# データ利活用_実践          640
# プロダクト開発_基礎         342
# デジタルマーケティング_基礎     316
# データ利活用_基礎          149
# データ                 35
# プロダクト開発_実践          24
# システム開発_実践           23
# DX勉強会               18
# Name: count, dtype: int64
# unique:  100
# 研修名
# 【DX基礎研修】DX概論                          453
# 【DX基礎研修】イントロダクション                     430
# コミュニケーション学 「ツッコミ講座」                   333
# 【DX基礎研修】デジタルマーケ事例① インフルエンサーマーケティング    306
# 【DX基礎研修】ディスラプター②                      249
#                                      ...
# 【MB03】SNSマーケティング基礎②0913,0919            7
# アプリ開発基礎②                                5
# 0827-28【PB06】アプリ開発基礎①　                  3
# 【MB04-02】インサイト分析ワーク                     2
# 【PB06】アプリ開発基礎②911,0912                  2
# Name: count, Length: 100, dtype: int64

# %% [markdown]
# ### hr_df

# %%
for col in hr_df.columns:
    print("unique: ", len(hr_df[col].unique()))
    print(hr_df[col].value_counts())
# Out:
# unique:  1550
# 社員番号
# M-J4K8nv5EWsiGlan6HRNA==    34
# t52oyqjeSnZj-IGMmj1DDQ==    33
# pns3kWfBUJPUOwgSUxpIlw==    30
# po_IhQLYtZpXRhor6gvX6w==    29
# sAsg-mw_7wLaL6SV_WO3aA==    28
#                             ..
# -K6Wmoe5UEPsygNo1tOiSg==     1
# 05IaeOcxSZ3C1yQmkdUvqg==     1
# y9gOZk9HYIgefsBFheDWdA==     1
# yFAGKNCnTcaE20floj8eMg==     1
# wyrwPBuTxLT4FxZmsdcHcg==     1
# Name: count, Length: 1550, dtype: int64
# unique:  12
# カテゴリ
# ビジネススキルアップ研修    2940
# 初期育成            1260
# スキルアップ支援        1154
# キャリア面談           362
# OJTトレーナー研修       324
# 中途研修             209
# 2年目研修            193
# 3等級昇格者研修         189
# マネジメント研修         174
# 3年目研修            150
# 管理職研修            112
# キャリア相談             9
# Name: count, dtype: int64
# unique:  20
# 研修名
# アカウンティング             918
# マーケティング              834
# 管理会計                 498
# 新入社員初期研修             420
# 新入社員半年後研修            420
# 新入社員3か月後研修           420
# 経営戦略                 366
# 新任課長研修               286
# ティーチング＆フィードバック研修     250
# 社内カウンセラーによるキャリア相談    214
# 中途研修                 209
# 2年目研修                193
# 3等級昇格者研修             189
# 組織行動とリーダーシップ         186
# 3年目研修                150
# 社外カウンセラーによるキャリア面談    148
# 財務計画・収益シミュレーション      138
# タイプ別コミュニケーション研修       74
# 個別キャリア相談               9
# Name: count, dtype: int64
# unique:  767
# 実施日
# 2024-12-01 00:00:00    316
# 2024-06-06 00:00:00    306
# 2023-07-07 00:00:00    252
# 2023-09-08 00:00:00    250
# 2023/7/10,2023/7/31    216
#                       ...
# 2022-09-23 00:00:00      1
# 2022-05-09 00:00:00      1
# 2023-08-29 00:00:00      1
# 2022-10-06 00:00:00      1
# 2022-06-26 00:00:00      1
# Name: count, Length: 767, dtype: int64

# %% [markdown]
# ### 結合

# %%
train_test_df = pd.concat([train_df, test_df])
train_test_df
# Out:
#                            社員番号               category  target
# 0      -2Sq3E0WkZj8pL7jxdL3Cg==        コンテンツ・サービス・デザイン     0.0
# 1      -2Sq3E0WkZj8pL7jxdL3Cg==  コーポレート管理部門/技術・データ・BPR     0.0
# 2      -2Sq3E0WkZj8pL7jxdL3Cg==            プロダクトマネジメント     0.0
# 3      -2Sq3E0WkZj8pL7jxdL3Cg==                マーケティング     0.0
# 4      -2Sq3E0WkZj8pL7jxdL3Cg==             事業企画・開発・研究     0.0
# ...                         ...                    ...     ...
# 11017  zxmtr2h4ypvsNq02K9AMJg==  コーポレート管理部門/技術・データ・BPR     NaN
# 11018  zxmtr2h4ypvsNq02K9AMJg==            プロダクトマネジメント     NaN
# 11019  zxmtr2h4ypvsNq02K9AMJg==                マーケティング     NaN
# 11020  zxmtr2h4ypvsNq02K9AMJg==             事業企画・開発・研究     NaN
# 11021  zxmtr2h4ypvsNq02K9AMJg==                     営業     NaN
#
# [18360 rows x 3 columns]

# %%
train_test_df["target"].isna().sum()
# Out:
# np.int64(11022)

# %%
train_df.shape

# %%
train_unique = train_df.drop_duplicates(subset="社員番号")
print(train_df.shape)
print(train_unique.shape)
# Out:
# (7338, 3)
# (1223, 3)

# %%
test_unique = test_df.drop_duplicates(subset="社員番号")
print(test_df.shape)
print(test_unique.shape)
# Out:
# (11022, 2)
# (1837, 2)

# %%
test_unique["target"] = np.nan
test_unique
# Out:
# /var/folders/jj/qyzht4v97h17n3fvl_hqbt7h0000gn/T/ipykernel_27746/1350756559.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_unique["target"] = np.nan
#                            社員番号         category  target
# 0      -1sqs0GXzpPJuAVKHUUFgg==  コンテンツ・サービス・デザイン     NaN
# 6      -4jh26kLzkU8JFQwdeQU9w==  コンテンツ・サービス・デザイン     NaN
# 12     -5W_JQCSTAYe2gGJMuT4_w==  コンテンツ・サービス・デザイン     NaN
# 18     -AUHIuzsGtdhhsPuX6dGLw==  コンテンツ・サービス・デザイン     NaN
# 24     -DyuCGlo_yVK2ddwpxupSA==  コンテンツ・サービス・デザイン     NaN
# ...                         ...              ...     ...
# 10992  zsZqwglfVER5ZvrJ2UWwRw==  コンテンツ・サービス・デザイン     NaN
# 10998  zwcjIiu_sqUs8akLOfuYKA==  コンテンツ・サービス・デザイン     NaN
# 11004  zxPKKLM85QljzRfp0yisow==  コンテンツ・サービス・デザイン     NaN
# 11010  zxY0Eflwm1tYj1Wt6vo_1g==  コンテンツ・サービス・デザイン     NaN
# 11016  zxmtr2h4ypvsNq02K9AMJg==  コンテンツ・サービス・デザイン     NaN
#
# [1837 rows x 3 columns]

# %%
train_test_unique = pd.concat([train_unique, test_unique])
merge = pd.merge(train_test_unique, career_df, on="社員番号", how="left")
merge = pd.merge(merge, dx_df, on="社員番号", how="left")
merge = pd.merge(merge, hr_df, on="社員番号", how="left")
merge
# Out:
#                            社員番号         category  target  \
# 0      -2Sq3E0WkZj8pL7jxdL3Cg==  コンテンツ・サービス・デザイン     0.0
# 1      -2Sq3E0WkZj8pL7jxdL3Cg==  コンテンツ・サービス・デザイン     0.0
# 2      -4taxxVbT1nU-J5fHWmDfQ==  コンテンツ・サービス・デザイン     0.0
# 3      -4taxxVbT1nU-J5fHWmDfQ==  コンテンツ・サービス・デザイン     0.0
# 4      -4taxxVbT1nU-J5fHWmDfQ==  コンテンツ・サービス・デザイン     0.0
# ...                         ...              ...     ...
# 43970  zxmtr2h4ypvsNq02K9AMJg==  コンテンツ・サービス・デザイン     NaN
# 43971  zxmtr2h4ypvsNq02K9AMJg==  コンテンツ・サービス・デザイン     NaN
# 43972  zxmtr2h4ypvsNq02K9AMJg==  コンテンツ・サービス・デザイン     NaN
# 43973  zxmtr2h4ypvsNq02K9AMJg==  コンテンツ・サービス・デザイン     NaN
# 43974  zxmtr2h4ypvsNq02K9AMJg==  コンテンツ・サービス・デザイン     NaN
#
#       自分の能力を発揮できる仕事上の得意分野が見つかっている\n 自分はどんな仕事をやりたいのか明らかである      \n  \
# 0                               NaN                           NaN
# 1                               NaN                           NaN
# 2                      4 そう思う／当てはまる                   3 どちらとも言えない
# 3                      4 そう思う／当てはまる                   3 どちらとも言えない
# 4                      4 そう思う／当てはまる                   3 どちらとも言えない
# ...                             ...                           ...
# 43970                           NaN                           NaN
# 43971                           NaN                           NaN
# 43972                           NaN                           NaN
# 43973                           NaN                           NaN
# 43974                           NaN                           NaN
#
#       自分は何を望んで今の仕事をしているのかわかっている\n 自分なりの職業的な生き方に関する目標・目的がはっきりしている\n  \
# 0                             NaN                              NaN
# 1                             NaN                              NaN
# 2                    4 そう思う／当てはまる                      3 どちらとも言えない
# 3                    4 そう思う／当てはまる                      3 どちらとも言えない
# 4                    4 そう思う／当てはまる                      3 どちらとも言えない
# ...                           ...                              ...
# 43970                         NaN                              NaN
# 43971                         NaN                              NaN
# 43972                         NaN                              NaN
# 43973                         NaN                              NaN
# 43974                         NaN                              NaN
#
#       自分のこれからのキャリアには、あまり関心がない\n これからのキャリアを、より充実したものにしたいと強く思う\n  \
# 0                           NaN                            NaN
# 1                           NaN                            NaN
# 2                  4 そう思う／当てはまる                   4 そう思う／当てはまる
# 3                  4 そう思う／当てはまる                   4 そう思う／当てはまる
# 4                  4 そう思う／当てはまる                   4 そう思う／当てはまる
# ...                         ...                            ...
# 43970                       NaN                            NaN
# 43971                       NaN                            NaN
# 43972                       NaN                            NaN
# 43973                       NaN                            NaN
# 43974                       NaN                            NaN
#
#       キャリア設計（職業生活の設計）は、自分にとって重要な課題である\n  ...  \
# 0                                   NaN  ...
# 1                                   NaN  ...
# 2                          4 そう思う／当てはまる  ...
# 3                          4 そう思う／当てはまる  ...
# 4                          4 そう思う／当てはまる  ...
# ...                                 ...  ...
# 43970                               NaN  ...
# 43971                               NaN  ...
# 43972                               NaN  ...
# 43973                               NaN  ...
# 43974                               NaN  ...
#
#       デジタルマーケティング施策（SNS 広告等）をデータで最適化できる 顧客・市場データを用いて新商品・サービス企画を立案できる  \
# 0                                   NaN                          NaN
# 1                                   NaN                          NaN
# 2                2 あまりそう思わない／あまり当てはまらない       2 あまりそう思わない／あまり当てはまらない
# 3                2 あまりそう思わない／あまり当てはまらない       2 あまりそう思わない／あまり当てはまらない
# 4                2 あまりそう思わない／あまり当てはまらない       2 あまりそう思わない／あまり当てはまらない
# ...                                 ...                          ...
# 43970                               NaN                          NaN
# 43971                               NaN                          NaN
# 43972                               NaN                          NaN
# 43973                               NaN                          NaN
# 43974                               NaN                          NaN
#
#       クラウド／DevOps 環境を構築し IaC で継続的デプロイを管理できる  \
# 0                                       NaN
# 1                                       NaN
# 2                    2 あまりそう思わない／あまり当てはまらない
# 3                    2 あまりそう思わない／あまり当てはまらない
# 4                    2 あまりそう思わない／あまり当てはまらない
# ...                                     ...
# 43970                                   NaN
# 43971                                   NaN
# 43972                                   NaN
# 43973                                   NaN
# 43974                                   NaN
#
#       デジタルツインや IoT データを用いたサプライチェーン最適化を提案・実装できる                研修実施日  \
# 0                                          NaN  2024-04-15 00:00:00
# 1                                          NaN  2024-04-16 00:00:00
# 2                       2 あまりそう思わない／あまり当てはまらない                  NaN
# 3                       2 あまりそう思わない／あまり当てはまらない                  NaN
# 4                       2 あまりそう思わない／あまり当てはまらない                  NaN
# ...                                        ...                  ...
# 43970                                      NaN                  NaN
# 43971                                      NaN                  NaN
# 43972                                      NaN                  NaN
# 43973                                      NaN                  NaN
# 43974                                      NaN                  NaN
#
#            研修カテゴリ            研修名_x          カテゴリ     研修名_y  \
# 0      リテラシー_DX基礎     【DX基礎研修】DX概論           NaN       NaN
# 1      リテラシー_DX基礎  【DX基礎研修】ものづくり概論           NaN       NaN
# 2             NaN              NaN      3等級昇格者研修  3等級昇格者研修
# 3             NaN              NaN  ビジネススキルアップ研修   マーケティング
# 4             NaN              NaN  ビジネススキルアップ研修   マーケティング
# ...           ...              ...           ...       ...
# 43970         NaN              NaN  ビジネススキルアップ研修      管理会計
# 43971         NaN              NaN  ビジネススキルアップ研修      管理会計
# 43972         NaN              NaN  ビジネススキルアップ研修      管理会計
# 43973         NaN              NaN  ビジネススキルアップ研修      管理会計
# 43974         NaN              NaN  ビジネススキルアップ研修      管理会計
#
#                          実施日
# 0                        NaN
# 1                        NaN
# 2        2023-06-02 00:00:00
# 3      2022/11/15,2022/11/29
# 4      2022/11/15,2022/11/29
# ...                      ...
# 43970  2023/10/23,2023/11/13
# 43971  2023/10/23,2023/11/13
# 43972  2023/10/23,2023/11/13
# 43973  2023/10/23,2023/11/13
# 43974  2023/10/23,2023/11/13
#
# [43975 rows x 54 columns]

# %%
# 一人当たりいくつ応募したか
train_df.groupby("社員番号")["target"].sum().value_counts()
# Out:
# target
# 0    968
# 1    223
# 2     30
# 3      2
# Name: count, dtype: int64

# %%
train_bool = train_df.groupby("社員番号")["target"].sum().reset_index()
train_bool["target"] = train_bool["target"] > 0

# %%
train_bool["target"].value_counts()
# Out:
# target
# False    968
# True     255
# Name: count, dtype: int64
