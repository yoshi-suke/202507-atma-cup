# %% [markdown]
# # データ・パッケージの読込

# %% [markdown]
# ## パッケージ読み込み

# %%
### 必要なパッケージ（ライブラリ）の読み込み ###
import pandas as pd             # データフレーム型変数を取り扱えるパッケージ"pandas"を読込み（以降"pd"と略記）
import matplotlib.pyplot as plt # グラフ描画のパッケージ"matplotlib"を読込み（以降"plt"と略記）
import seaborn as sns           # 上記matplotlibをベースにした高機能可視化モジュール"saeborn"を読込み（以降"sns"と略記）
import numpy as np              # 数値演算のためのパッケージ"numpy"を読込み（以降"np"と略記）

# %% [markdown]
# ## 参考：描画設定
# ※重なりなどの描画崩れや、文字化けなど、描画がうまくいかない場合

# %%
### 以下、描画の細かいデザイン設定 ###

# 出力されるグラフ画像の解像度を上げる
# %config InlineBackend.figure_formats = {'png', 'retina'}

# グラフのサイズ指定
# plt.rcParams['figure.figsize'] = 10, 5

# 文字化け対策にフォント指定（Win/Macなどの環境に依らず、横断的に設定）
plt.rcParams['font.sans-serif'] = ['Hiragino Maru Gothic Pro', 'Yu Gothic', 'Meirio', 'Takao',
                                   'IPAexGothic', 'IPAPGothic', 'VL PGothic', 'Noto Sans CJK JP']

# フォントサイズ一括指定
# plt.rcParams['font.size'] = 14

# %% [markdown]
# ## データ読み込み

# %%
### データの読込 ###
# 製造データ
df_process = pd.read_excel("data/20240806/演習02_電子部品_寸法データ.xlsx")
# 品質データ
df_quality = pd.read_excel("data/20240806/演習02_電子部品_品質データ.xlsx")

# %% [markdown]
# ## データ結合

# %%
### 製造データと品質データの結合 ###
df = pd.merge(df_process, df_quality)        # 'ID'をキーとしてデータ結合（内部結合）

# %%
# 結合後データの行数・列数を確認
#各自入力
df
# Out:
#         ID     高さ    重量   上幅   中幅   下幅 検品結果
# 0   A00001  16.13  4.71  8.3  5.8  8.7  不良品
# 1   A00003  16.24  4.84  8.3  6.0  8.9  不良品
# 2   A00004  16.00  4.54  8.0  5.7  8.0   良品
# 3   A00005  15.85  5.07  7.9  6.0  8.7  不良品
# 4   A00006  15.74  4.11  7.8  5.6  8.1   良品
# 5   A00008  16.31  5.20  8.2  6.1  9.1  不良品
# 6   A00009  15.77  4.49  8.5  5.8  8.6   良品
# 7   A00010  15.58  4.58  8.8  5.8  8.6   良品
# 8   A00011  16.19  4.40  8.2  5.8  8.8   良品
# 9   A00012  16.04  4.24  8.4  5.6  8.5   良品
# 10  A00015  15.71  4.33  8.5  5.5  8.5   良品
# 11  A00016  15.88  4.44  7.9  5.8  8.5   良品
# 12  A00017  16.26  5.04  8.8  6.2  9.2  不良品
# 13  A00018  16.14  4.52  8.2  5.6  8.3   良品
# 14  A00019  15.99  4.88  8.6  5.7  8.8   良品
# 15  A00020  16.70  4.83  8.2  5.8  8.7   良品
# 16  A00022  15.54  4.52  8.1  5.6  8.5   良品
# 17  A00023  15.94  4.87  8.0  6.2  8.3  不良品
# 18  A00027  17.02  5.25  8.6  6.0  8.8  不良品
# 19  A00028  16.28  4.34  8.1  5.7  8.4   良品
# ...

# %% [markdown]
# # データの理解（観察）

# %% [markdown]
# ## データ概観把握

# %%
### 要約統計量 ###
#各自入力
df.describe()
# Out:
#               高さ        重量         上幅         中幅         下幅
# count  30.000000  30.00000  30.000000  30.000000  30.000000
# mean   16.040000   4.69600   8.306667   5.816667   8.626667
# std     0.393884   0.31332   0.342338   0.178274   0.330030
# min    15.210000   4.11000   7.800000   5.500000   8.000000
# 25%    15.790000   4.46000   8.100000   5.700000   8.500000
# 50%    16.000000   4.67500   8.250000   5.800000   8.600000
# 75%    16.255000   4.86250   8.500000   5.975000   8.800000
# max    17.020000   5.42000   9.400000   6.200000   9.700000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      30 non-null     object
#  1   高さ      30 non-null     float64
#  2   重量      30 non-null     float64
#  3   上幅      30 non-null     float64
#  4   中幅      30 non-null     float64
#  5   下幅      30 non-null     float64
#  6   検品結果    30 non-null     object
# dtypes: float64(5), object(2)
# memory usage: 1.8+ KB

# %%
### 欠測値確認 ###
#各自入力
df.isna().sum()
# Out:
# ID      0
# 高さ      0
# 重量      0
# 上幅      0
# 中幅      0
# 下幅      0
# 検品結果    0
# dtype: int64

# %% [markdown]
# ## データ可視化（グラフ）

# %% [markdown]
# ### ヒストグラム

# %%
#各自入力
df.hist()
plt.tight_layout()

# %% [markdown]
# ### 箱ひげ図

# %%
#各自入力
df.boxplot()
# Out:
# <Axes: >

# %% [markdown]
# ### 散布図

# %%
#各自入力

# %% [markdown]
# ### 散布図行列

# %%
#各自入力
sns.pairplot(df)

# %%
sns.pairplot(df, hue="検品結果", corner=True)

# %% [markdown]
# ### 相関行列

# %%
### 相関行列による変数間の関係性確認 ###
sns.heatmap(df.corr(numeric_only=True), annot=True, fmt=".2f", cmap="Blues", )

# pandasのv2.0.0以降、数値以外のデータが入っているとエラーになるため、
# 数値以外を含む場合、数値データのみに絞り込むオプション numeric_only=True を指定する
# （今回のデータは数値のみなので、オプション無しでもエラーなく実行できる）
# Out:
# <Axes: >

# %%
### 相関行列のお化粧（ヒートマップ） ###

# 描画の設定
colormap = plt.cm.RdBu_r                #カラーマップの設定 (RdBu:赤〜青 ⇔ RdBu_r:青〜赤)
plt.rcParams['figure.figsize'] = 10, 5  # Figureサイズの指定

# 相関行列の算出
corr = df.corr(numeric_only=True) #数値以外も含まれている場合には、numeric_only=True を引数に指定

# ヒートマップの描画
sns.heatmap(corr,linewidths=0.1, linecolor='white', #相関行列df.corr()を引数としヒートマップ作成	
            vmax=1.0, vmin=-1.0, cmap=colormap,     #最大値、最小値、カラーマップの指定 
            annot=True, fmt='.2f',                  #各セル内に表示する数値の設定
            mask=np.triu(corr) #相関行列の右上半分を隠したい場合はこのコメントを解除
           )

            # linewidths/linecolor: 格子線の太さ/色
            # cmap:                 カラーマップの指定
            # vmax/vmin:            最大値/最小値
            # annot:                各要素への数値表示
            # annot_kws={'fontsize':8}: 各要素内に表示する数値の文字サイズを指定
            # fmt='.2f':            各要素内に表示する数値の小数点桁数を指定（'.2f'で小数第二位まで）
            # mask:                 可視化から除外する対象
# Out:
# <Axes: >

# %% [markdown]
# # データ加工

# %% [markdown]
# ## ダミー変数化

# %%
### 目的変数のダミー変数化 ###
# 検品結果を1,0の数値に変換
df['検品結果'] = np.where(df["検品結果"] == "不良品", 1, 0)

# %% [markdown]
# # モデル作成・評価

# %% [markdown]
# ## ロジスティック回帰による不良要因の分析

# %% [markdown]
# ### ロジスティック回帰モデル構築

# %%
### ロジスティック回帰分析 ###
### ①ライブラリの読み込み ### 
from sklearn import linear_model # 機械学習パッケージに含まれた回帰分析モジュール"linear_model"を読込

### ②説明変数・目的変数のセット ###
# 説明変数のセット
X = df.drop(columns=["ID", "検品結果"])

# 目的変数のセット
Y = df["検品結果"]

### ③モデル構築 ###
# ロジスティック回帰モデルを作成
model = linear_model.LogisticRegression()
# model = linear_model.LogisticRegression(class_weight="balanced")   # 重みづけ
model.fit(X, Y)
# 各自入力（タイタニック号データ分析のコードを転用）
# Out:
# LogisticRegression()

# %% [markdown]
# ### 結果の出力

# %%
### ④結果の出力 ###
# 各自入力（タイタニック号データ分析のコードを転用）

# 偏回帰係数の出力
display( pd.DataFrame({"Variables":X.columns, "Coefficients":model.coef_.reshape(-1,)}) )
#もしくは
#display( pd.concat( [pd.DataFrame(X.columns, columns=['Variables']), pd.DataFrame(model.coef_.T, columns=['Coefficients'])], axis=1) )

# 切片の出力
print( '切片:', model.intercept_ )

# 正解率の出力（全データのうち、正解した件数の割合）
print( '正解率:', model.score(X, Y) )
# Out:
#   Variables  Coefficients
# 0        高さ     -0.117574
# 1        重量      1.296292
# 2        上幅     -0.552288
# 3        中幅      1.352445
# 4        下幅      0.243798
# 切片: [-10.32660156]
# 正解率: 0.8

# %% [markdown]
# ### モデル評価

# %%
## 混同行列、各種精度指標の可視化 ###
# 各自入力（タイタニック号データ分析のコードを転用）
Y_pred = model.predict(X)  # モデルに説明変数を入力して、予測結果を出力
results = pd.DataFrame( {'実測値':Y, '予測値':Y_pred}, columns=['実測値', '予測値'] ) # データフレームに実測値、予測結果を格納

probs = model.predict_proba(X) # モデル.predict_proba(説明変数) で モデルに説明変数を入力したときの予測「確率」を抽出
probs = pd.DataFrame(probs)    # データフレーム型に変換

results['確率(Prob)'] = probs[1]     # 参考データとしてresultsのデータフレームにくっつける

display(results)
# Out:
#     実測値  予測値  確率(Prob)
# 0     1    0  0.323815
# 1     1    0  0.435004
# 2     0    0  0.253204
# 3     1    1  0.563332
# 4     0    0  0.166750
# 5     1    1  0.607355
# 6     0    0  0.247128
# 7     0    0  0.242197
# 8     0    0  0.256242
# 9     0    0  0.153235
# 10    0    0  0.148748
# 11    0    0  0.292195
# 12    1    1  0.515727
# 13    0    0  0.214747
# 14    0    0  0.315179
# 15    0    0  0.356055
# 16    0    0  0.245638
# 17    1    1  0.525626
# 18    1    0  0.497061
# 19    0    0  0.208914
# 20    0    0  0.260922
# 21    0    0  0.258922
# 22    1    0  0.487656
# 23    0    0  0.369719
# 24    1    0  0.352791
# 25    0    0  0.284633
# 26    1    0  0.348417
# 27    0    0  0.248029
# 28    0    0  0.386786
# 29    0    0  0.434018

# %%
#ライブラリ読込：モデル評価のためのライブラリ
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score

#各種 精度指標の出力
print('混同行列 (confusion matrix) = \n', confusion_matrix(y_true= Y, y_pred= Y_pred, labels=[1,0]))
print('正解率 (accuracy) = ', accuracy_score(y_true= Y, y_pred= Y_pred))
print('適合率 (precision) = ', precision_score(y_true= Y, y_pred= Y_pred, pos_label=1))
print('再現率 (recall) = ', recall_score(y_true= Y, y_pred= Y_pred, pos_label=1))
print('F値 (f1 score) = ', f1_score(y_true= Y, y_pred= Y_pred, pos_label=1))
# Out:
# 混同行列 (confusion matrix) =
#  [[ 4  6]
#  [ 0 20]]
# 正解率 (accuracy) =  0.8
# 適合率 (precision) =  1.0
# 再現率 (recall) =  0.4
# F値 (f1 score) =  0.5714285714285714

# %% [markdown]
# ## アンダーサンプリング

# %%
# ライブラリの読み込み
from imblearn.under_sampling import RandomUnderSampler

# 正例の数を保存
positive_num = Y.value_counts()[1]

# 負例を正例の数に合わせる（無作為抽出：アンダーサンプリング）
under = RandomUnderSampler( sampling_strategy={0:positive_num, 1:positive_num}, random_state=0 )

# 学習用データに反映
X_under, Y_under = under.fit_resample(X, Y)

# %%
# Before:クラスの数確認
Y.value_counts()
# Out:
# 検品結果
# 0    20
# 1    10
# Name: count, dtype: int64

# %%
# After:クラスの数確認
Y_under.value_counts()
# Out:
# 検品結果
# 0    10
# 1    10
# Name: count, dtype: int64

# %% [markdown]
# ## ロジスティック回帰モデル再構築

# %% [markdown]
# ### ロジスティック回帰モデル構築

# %%
### ロジスティック回帰分析 ###
# 各自入力（タイタニック号データ分析のコードを転用）
model = linear_model.LogisticRegression()
model.fit(X_under, Y_under)
# Out:
# LogisticRegression()

# %% [markdown]
# ### 結果の出力

# %%
## 混同行列、各種精度指標の可視化 ###
# 各自入力（タイタニック号データ分析のコードを転用）

# 偏回帰係数の出力
display( pd.DataFrame({"Variables":X_under.columns, "Coefficients":model.coef_.reshape(-1,)}) )
#もしくは
#display( pd.concat( [pd.DataFrame(X.columns, columns=['Variables']), pd.DataFrame(model.coef_.T, columns=['Coefficients'])], axis=1) )

# 切片の出力
print( '切片:', model.intercept_ )

# 正解率の出力（全データのうち、正解した件数の割合）
print( '正解率:', model.score(X_under, Y_under) )
# Out:
#   Variables  Coefficients
# 0        高さ     -0.102453
# 1        重量      1.058580
# 2        上幅     -0.483646
# 3        中幅      1.064189
# 4        下幅      0.007135
# 切片: [-5.67622254]
# 正解率: 0.8

# %% [markdown]
# ### モデル評価

# %%
## 混同行列、各種精度指標の可視化 ###
#モデル予測結果の取得
Y_pred_under = model.predict(X_under)  # モデルに説明変数を入力して、予測結果を出力

#ライブラリ読込：モデル評価のためのライブラリ
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score

#各種 精度指標の出力
print('混同行列 (confusion matrix) = \n', confusion_matrix(y_true= Y_under, y_pred= Y_pred_under, labels=[1,0]))
print('正解率 (accuracy) = ', accuracy_score(y_true= Y_under, y_pred= Y_pred_under))
print('適合率 (precision) = ', precision_score(y_true= Y_under, y_pred= Y_pred_under, pos_label=1))
print('再現率 (recall) = ', recall_score(y_true= Y_under, y_pred= Y_pred_under, pos_label=1))
print('F値 (f1 score) = ', f1_score(y_true= Y_under, y_pred= Y_pred_under, pos_label=1))
# Out:
# 混同行列 (confusion matrix) =
#  [[8 2]
#  [2 8]]
# 正解率 (accuracy) =  0.8
# 適合率 (precision) =  0.8
# 再現率 (recall) =  0.8
# F値 (f1 score) =  0.8

# %% [markdown]
# ## 決定木分析による不良要因の分析

# %% [markdown]
# ### 決定木分析モデル構築

# %%
### 決定木分析 ###
### ①ライブラリの読み込み ### 
from sklearn import tree     # 機械学習パッケージに含まれた決定木分析モジュール"tree"を読込

### ②説明変数・目的変数のセット ###
# 説明変数のセット
X = df.drop(columns=["ID", "検品結果"])

# 目的変数のセット
Y = df["検品結果"]

# 決定木モデルを作成
# 各自入力（タイタニック号データ分析のコードを転用）

model = tree.DecisionTreeClassifier(max_depth=3, criterion = 'gini', random_state=0)  # インスタンス化（関数を使える状態にする
model.fit(X, Y)
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=0)

# %% [markdown]
# ### モデル可視化

# %% [markdown]
# #### dtreevizによる可視化

# %%
# 日本語文字化け対策 → 最初に実行していれば不要
# plt.rcParams['font.family'] = 'Hiragino Maru Gothic Pro'   # Windowsの場合: 'Yu Mincho'  / 'TakaoGothic' など

# %%
### スマート可視化ツール "dtreeviz" を使った可視化 ###

# 各自入力（タイタニック号データ分析のコードを転用）

# %%
### dtreevizを使わない可視化方法 ###

# 各自入力（タイタニック号データ分析のコードを転用）

# %%
### 変数重要度一覧 ###

# 各自入力（タイタニック号データ分析のコードを転用）

# %% [markdown]
# #### 参考：dtreeviz で class_names を自動設定する方法

# %%
# ダミー変数化用の対応関係を辞書型で定義
dummy_dict = {'良品': 0, '不良品':1}
print(dummy_dict)

# %%
### 目的変数のダミー変数化 ###
df['検品結果'] = df['検品結果'].replace(dummy_dict)

# %%
### 方法①：辞書型データを変換してクラス名リストを作成する方法 ###

# 辞書の対応関係 (key, value) を逆転
dummy_dict_rev = dict( map(reversed,dummy_dict.items()) )
print(dummy_dict_rev)

# 文字列結合
dummy_class_names = [ ':'.join(str(i) for i in x) for x in list(dummy_dict_rev.items()) ]
print(dummy_class_names)

# %%
### 方法②：forループで回してリストに格納する方法 ###

# クラス名格納用の空リストを準備
dummy_class_names = []

# 空リストに、逐次、辞書型データを結合した文字列（「ダミー値:クラス名」の形式）を格納
for key, value in dummy_dict.items():
    dummy_class_names.append( str(value)+':'+key )

# 結果の出力
print(dummy_class_names)

# %%
import matplotlib
print(matplotlib.matplotlib_fname())

# %%
# 描画サイズの指定
fig, ax = plt.subplots( figsize=(40,40) )

tree.plot_tree(model,                                #描画対象の決定木モデル
               feature_names = X.columns.to_list(),  #決定木の分割条件に記載する説明変数名称
               class_names =  ['0:良品', '1:不良品'],     #凡例に記載する目的変数名称
               fontsize = 12,                        #フォントサイズの調整
               filled=True,                          #各ノードの色付け有無
               rounded=True,                         #各ノードの形状（角丸四角とするか）
               proportion=True                       #比率を出力するか
              )
# Out:
# [Text(0.6, 0.875, '中幅 <= 5.95\ngini = 0.444\nsamples = 100.0%\nvalue = [0.667, 0.333]\nclass = 0:良品'),
#  Text(0.4, 0.625, '重量 <= 4.695\ngini = 0.165\nsamples = 73.3%\nvalue = [0.909, 0.091]\nclass = 0:良品'),
#  Text(0.5, 0.75, 'True  '),
#  Text(0.2, 0.375, 'gini = 0.0\nsamples = 50.0%\nvalue = [1.0, 0.0]\nclass = 0:良品'),
#  Text(0.6, 0.375, '重量 <= 4.825\ngini = 0.408\nsamples = 23.3%\nvalue = [0.714, 0.286]\nclass = 0:良品'),
#  Text(0.4, 0.125, 'gini = 0.444\nsamples = 10.0%\nvalue = [0.333, 0.667]\nclass = 1:不良品'),
#  Text(0.8, 0.125, 'gini = 0.0\nsamples = 13.3%\nvalue = [1.0, 0.0]\nclass = 0:良品'),
#  Text(0.8, 0.625, 'gini = 0.0\nsamples = 26.7%\nvalue = [0.0, 1.0]\nclass = 1:不良品'),
#  Text(0.7, 0.75, '  False')]

# %%
### 変数重要度一覧 ###
features = X.columns                      # 変数名を取得
importances = model.feature_importances_  # モデルから各変数の重要度を取得
indices = np.argsort(importances)         # 並び順を定義（大きい順序）

# グラフ描画
plt.figure(figsize=(6,6)) # グラフサイズの指定
plt.barh(range(len(indices)), importances[indices], color='b', align='center') # 横棒グラフ
plt.yticks(range(len(indices)), features[indices]) # 変数名を描画
plt.show()

# %% [markdown]
# ### モデル評価

# %%
## 混同行列、各種精度指標の可視化 ###

# 各自入力（タイタニック号データ分析のコードを転用）
#モデルによる予測結果の取得
Y_pred = model.predict(X)

#ライブラリ読込：モデル評価のためのライブラリ
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score

#各種 精度指標の出力
print('混同行列 (confusion matrix) = \n', confusion_matrix(y_true= Y, y_pred= Y_pred, labels=[1,0]))
print('正解率 (accuracy) = ', accuracy_score(y_true= Y, y_pred= Y_pred))
print('適合率 (precision) = ', precision_score(y_true= Y, y_pred= Y_pred, pos_label=1))
print('再現率 (recall) = ', recall_score(y_true= Y, y_pred= Y_pred, pos_label=1))
print('F値 (f1 score) = ', f1_score(y_true= Y, y_pred= Y_pred, pos_label=1))
# Out:
# 混同行列 (confusion matrix) =
#  [[10  0]
#  [ 1 19]]
# 正解率 (accuracy) =  0.9666666666666667
# 適合率 (precision) =  0.9090909090909091
# 再現率 (recall) =  1.0
# F値 (f1 score) =  0.9523809523809523

# %% [markdown]
# ## ランダムフォレスト

# %%
### ランダムフォレスト ###

### ①ライブラリの読み込み ### 
from sklearn.ensemble import RandomForestClassifier  # ensembleモジュールからRandomForestClassifierクラスを読込

### ②説明変数・目的変数のセット ###
# 説明変数のセット
X = df.drop( columns=['ID', '検品結果'] )  #説明変数; df.drop(columns=[対象列名])で、除外対象カラムを指定。df[ [列名] ]の指定でも可
# 目的変数のセット
Y = df['検品結果']

### ③モデル構築 ###
forest = RandomForestClassifier(random_state=0, class_weight='balanced') # インスタンス生成
                                # random_state固定で再現性担保
                                # class_weight='balanced'で不均衡データに対する重み調整
    
forest.fit(X, Y)           # ランダムフォレスト実行
# Out:
# RandomForestClassifier(class_weight='balanced', random_state=0)

# %%
### ④結果の出力 ###
### 変数重要度の可視化 ###
features =    X.columns                     # 説明変数名称を取得
importances = forest.feature_importances_   # 変数重要度の取得
indices =     np.argsort(-importances)      # 変数重要度の大きい順に並べた順番を取得（降順にするためにマイナスを付与）

sns.barplot(x=importances, y=features, order=features[indices]) # 横向き棒グラフで大きい順に描画
# Out:
# <Axes: ylabel='None'>

# %% [markdown]
# ### モデル評価

# %%
## 混同行列、各種精度指標の可視化 ###
#モデルによる予測結果の取得
Y_pred = forest.predict(X)

#ライブラリ読込：モデル評価のためのライブラリ
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score

#各種 精度指標の出力
print('混同行列 (confusion matrix) = \n', confusion_matrix(y_true= Y, y_pred= Y_pred, labels=[1,0]))
print('正解率 (accuracy) = ', accuracy_score(y_true= Y, y_pred= Y_pred))
print('適合率 (precision) = ', precision_score(y_true= Y, y_pred= Y_pred, pos_label=1))
print('再現率 (recall) = ', recall_score(y_true= Y, y_pred= Y_pred, pos_label=1))
print('F値 (f1 score) = ', f1_score(y_true= Y, y_pred= Y_pred, pos_label=1))
# Out:
# 混同行列 (confusion matrix) =
#  [[10  0]
#  [ 0 20]]
# 正解率 (accuracy) =  1.0
# 適合率 (precision) =  1.0
# 再現率 (recall) =  1.0
# F値 (f1 score) =  1.0

# %% [markdown]
# ## クラスタリングによる不良モード分類

# %% [markdown]
# ### k-meansクラスタリングモデル構築

# %%
### ①ライブラリの読み込み ### 
from sklearn.cluster import KMeans # 機械学習パッケージに含まれたKMeansモジュール"KMeans"を読込

### ②説明変数、ハイパーパラメーターのセット ###
X = df.drop( columns=['ID', '検品結果'] )  #df.drop( columns=[対象列名] )で、除外対象のカラムを指定

# クラスタ数の設定
n = 3

### ③モデル構築 ###
# クラスタリング
model = KMeans( n_clusters=n, random_state=0 )  #クラスタリングの実行準備
                                                # オプションの説明：
                                                # n_clustersでクラスタ数指定
                                                # random_state=数値固定 でモデルの再現性を保持（乱数のシードを固定）
                                                # init='k-means++' or 'random' で初期クラスタ中心の配置方法を指定。defaultは'k-means++'
model.fit(X) #Xを説明変数としてクラスタリング実行
# Out:
# KMeans(n_clusters=3, random_state=0)

# %% [markdown]
# ### 結果の出力

# %%
### ④結果の出力 ###
### 所属クラスタ、重心座標の出力 ###
print(model.labels_) # 各データ点が所属するクラスタ
print(model.cluster_centers_) # 各クラスタの重心座標
# Out:
# [2 2 2 2 0 1 0 0 2 2 0 2 1 2 2 1 0 2 1 2 2 2 0 1 2 2 2 0 2 1]
# [[15.56571429  4.46142857  8.21428571  5.71428571  8.42857143]
#  [16.59166667  5.12333333  8.63333333  5.95        9.05      ]
#  [16.04058824  4.64176471  8.22941176  5.81176471  8.55882353]]

# %%
### 各クラスタに所属するデータ件数 ###

# %% [markdown]
# ### 元データへのクラスタ番号紐付け

# %%
### 元のdataframeにクラスタ番号を追加 ###
df['cluster'] = model.labels_

# %%
df #紐付け結果確認

# %%
### 各クラスタに所属するデータ件数確認 ###
df['cluster'].value_counts()
# Out:
# cluster
# 2    17
# 0     7
# 1     6
# Name: count, dtype: int64

# %% [markdown]
# ## k-meansクラスタリングモデルの評価

# %% [markdown]
# ### 最適なクラスタ数の確認（Elbow法）

# %%
SSE = []                      #クラスタ評価関数（クラスタ内誤差平方和: SSE）を格納するリストを準備

for i in range(1,7):          #クラスタ数を1から6まで振って順次k-meansを実行：range(start, stop)で start ≦ i < stop の連番を生成
    model = KMeans(n_clusters=i, random_state=0) #クラスタリングの実行準備
    model.fit(X)                                 #Xを説明変数としてk-meansクラスタリングの計算を実行
    SSE.append(model.inertia_)                   #各クラスタ内のクラスタ内誤差平方和を取得し、リストに格納 ※inertiaは慣性という意味
                                                 #（各データが所属クラスタの中心からどれだけ離れているか）
plt.plot(range(1,7), SSE, marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('SSE (Sum of Squared Errors)')
plt.show()

# %% [markdown]
# ### 箱ひげ図によるクラスタリング結果の確認（各クラスタの特徴探索）

# %%
df_target.columns

# %%
# 複数を並べて表示するために、subplotを定義
row_num = 2 #subplotsの縦の数 
col_num = 3 #subplotsの横の数
fig, axes = plt.subplots(row_num, col_num, figsize=(20,10)) #plt.subplots(縦の数, 横の数), figsize=(横の長さ,縦の長さ)

# 可視化対象外のカラムを除外（ID, 検品結果）
df_target = df.drop(columns=['ID', '検品結果'])

# カラムごとにループを回して、クラスタごとの箱ひげ図を描画
for i, col in enumerate( df_target.columns ):
    j, k = divmod(i, col_num) #描くグラフ位置を指定（横方向のグラフ個数colで割った商と余り）
    sns.boxplot(x='cluster', y=col, data=df_target, ax=axes[j,k]) #該当するカラムの箱ひげ図を指定の位置に描画
    
# グラフが重ならないように調整
plt.tight_layout()

# %% [markdown]
# ## 決定木による各クラスタ間の傾向分析

# %% [markdown]
# ### 決定木分析モデル構築

# %%
### 決定木分析 ###
from sklearn import tree     # 機械学習パッケージに含まれた決定木分析モジュール"tree"を読込

# 説明変数のセット
X = df.drop( columns=['ID', '検品結果', 'cluster'] )  #df.drop( columns=[対象列名] )で、除外対象のカラムを指定
# X = df[ ['[閲覧]データドリブン・マーケティング体制支援	', '[閲覧]コンテンツマーケティング運用支援', ....] ] #列名のリストで指定する場合

# 目的変数のセット
Y = df['cluster']

# 決定木モデルを作成
model = tree.DecisionTreeClassifier(max_depth=3, criterion = 'gini', random_state=0, class_weight='balanced')  # インスタンス化
    # 各種設定パラメータの説明
    # tree.DecisionTreeRegressor(max_depth=3) とすれば、回帰木
    # max_depth: ツリーの最大深さ
    # criterion: データの分割指標を "gini"（ジニ係数） or "entropy" （情報エントロピー）で指定
    # random_state: 乱数のシード値。指定することで再分析時の再現性を担保
    # class_weight: 不均衡データに対する重みづけ ='balanced'
    
model.fit(X, Y)                            # モデル構築（フィッティング）
# Out:
# DecisionTreeClassifier(class_weight='balanced', max_depth=3, random_state=0)

# %% [markdown]
# ### モデル可視化

# %%
### スマート可視化ツール "dtreeviz" を使った可視化 ###

import dtreeviz # 決定木可視化ライブラリを読み込み

viz_model = dtreeviz.model(model,
               X,                                 # 説明変数
               Y,                                 # 目的変数
               feature_names = X.columns,         # 決定木の分割条件に記載する説明変数名称
               target_name = Y.name,              # 凡例に記載する目的変数名称
               class_names = ['Cluster0', 'Cluster1', 'Cluster2'],  # 凡例に記載するクラス名称
              ) 

# 読み込んだ決定木モデルを描画
viz_model.view(
                fontname = 'Yu Gothic',              # 文字化け防止のためのフォント設定（Windows）
#                 fontname='Hiragino Maru Gothic Pro', # for Mac
                label_fontsize = 18,                 # 説明変数の文字サイズ
                ticks_fontsize = 14,                 # 目盛り数字の文字サイズ
                title = '決定木分析結果',               # グラフタイトル
                title_fontsize = 20,                 # グラフタイトルの文字サイズ
                scale = 1.2                          # 拡大率（描画サイズを拡大・縮小）
              )

# %%
### dtreevizを使わない可視化方法 ###
# 描画サイズの指定
fig, ax = plt.subplots( figsize=(40,40) )

tree.plot_tree(model,                                #描画対象の決定木モデル
               feature_names = X.columns.to_list(),  #決定木の分割条件に記載する説明変数名称
               class_names = ['Cluster0', 'Cluster1', 'Cluster2'], #凡例に記載する目的変数名称
               fontsize = 12,                        #フォントサイズの調整
               filled=True,                          #各ノードの色付け有無
               rounded=True,                         #各ノードの形状（角丸四角とするか）
               proportion=True                       #比率を出力するか
              )
# Out:
# [Text(0.5, 0.875, '高さ <= 15.81\ngini = 0.667\nsamples = 100.0%\nvalue = [0.333, 0.333, 0.333]\nclass = Cluster0'),
#  Text(0.25, 0.625, '重量 <= 4.605\ngini = 0.105\nsamples = 26.7%\nvalue = [0.944, 0.0, 0.056]\nclass = Cluster0'),
#  Text(0.375, 0.75, 'True  '),
#  Text(0.125, 0.375, '中幅 <= 5.55\ngini = 0.0\nsamples = 20.0%\nvalue = [1.0, 0.0, 0.0]\nclass = Cluster0'),
#  Text(0.0625, 0.125, 'gini = 0.0\nsamples = 3.3%\nvalue = [1.0, 0.0, 0.0]\nclass = Cluster0'),
#  Text(0.1875, 0.125, 'gini = 0.0\nsamples = 16.7%\nvalue = [1.0, 0.0, 0.0]\nclass = Cluster0'),
#  Text(0.375, 0.375, '重量 <= 4.72\ngini = 0.413\nsamples = 6.7%\nvalue = [0.708, 0.0, 0.292]\nclass = Cluster0'),
#  Text(0.3125, 0.125, 'gini = 0.0\nsamples = 3.3%\nvalue = [0.0, 0.0, 1.0]\nclass = Cluster2'),
#  Text(0.4375, 0.125, 'gini = -0.0\nsamples = 3.3%\nvalue = [1.0, 0.0, 0.0]\nclass = Cluster0'),
#  Text(0.75, 0.625, '高さ <= 16.25\ngini = 0.5\nsamples = 73.3%\nvalue = [0.0, 0.515, 0.485]\nclass = Cluster1'),
# ...

# %% [markdown]
# ### クラスタ間での不良率の違い

# %%
display( pd.crosstab(df['cluster'], df['検品結果']) )

display( pd.crosstab(df['cluster'], df['検品結果'], normalize='index') )
# Out:
# 検品結果      0  1
# cluster
# 0         6  1
# 1         3  3
# 2        11  6
# 検品結果            0         1
# cluster
# 0        0.857143  0.142857
# 1        0.500000  0.500000
# 2        0.647059  0.352941

# %%
SSE = []                      #クラスタ評価関数（クラスタ内誤差平方和: SSE）を格納するリストを準備

for i in range(1,7):          #クラスタ数を1から6まで振って順次k-meansを実行：range(start, stop)で start ≦ i < stop の連番を生成
    model = KMeans(n_clusters=i, random_state=0) #クラスタリングの実行準備
    model.fit(X)                                 #Xを説明変数としてk-meansクラスタリングの計算を実行
    SSE.append(model.inertia_)                   #各クラスタ内のクラスタ内誤差平方和を取得し、リストに格納 ※inertiaは慣性という意味
                                                 #（各データが所属クラスタの中心からどれだけ離れているか）
plt.plot(range(1,7), SSE, marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('SSE (Sum of Squared Errors)')
plt.show()
