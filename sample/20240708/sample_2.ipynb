# %%
import os

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
plt.rcParams['font.family'] = "MS Gothic"

# %%
DATA_DIR = "./data"

# %%
fpath = os.path.join(DATA_DIR, "演習01_タイタニック生存_学習データ.xlsx")
df_titanic = pd.read_excel(fpath)
df_titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df_titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df_titanic.describe(include="O")
# Out:
#                        Name   Sex  Ticket Cabin Embarked
# count                   891   891     891   204      889
# unique                  891     2     681   147        3
# top     Dooley, Mr. Patrick  male  347082    G6        S
# freq                      1   577       7     4      644

# %%
sns.heatmap(df_titanic.corr(numeric_only=True), annot=True, fmt=".2f", cmap="Blues", )
# Out:
# <Axes: >

# %%
pd.crosstab(df_titanic["Pclass"], df_titanic["Survived"])
# Out:
# Survived    0    1
# Pclass
# 1          80  136
# 2          97   87
# 3         372  119

# %%
pd.crosstab(df_titanic["Pclass"], df_titanic["Survived"], normalize="index")
# Out:
# Survived         0         1
# Pclass
# 1         0.370370  0.629630
# 2         0.527174  0.472826
# 3         0.757637  0.242363

# %%
pd.crosstab(df_titanic["Pclass"], df_titanic["Survived"], values=df_titanic["Age"], aggfunc="mean")
# Out:
# Survived          0          1
# Pclass
# 1         43.695312  35.368197
# 2         33.544444  25.901566
# 3         26.555556  20.646118

# %%
sns.histplot(df_titanic["Fare"], bins=10)
# Out:
# <Axes: xlabel='Fare', ylabel='Count'>

# %%
df_titanic.hist()
plt.tight_layout()

# %%
sns.jointplot(df_titanic, x="Age", y="Fare")

# %%
sns.pairplot(df_titanic, hue="Survived")

# %%
df_titanic.boxplot(column="Fare")
# Out:
# <Axes: >

# %%
fpath = os.path.join(DATA_DIR, "演習02_顧客マスタ.xlsx")
df_customer = pd.read_excel(fpath)
df_customer
# Out:
#         顧客ID         名前  年齢         誕生日  性別     職業
# 0       1456      Abbey  16  2000/05/31  女性    ナース
# 1       2424      Ryder  16  2000/05/07  男性    会社員
# 2       2771  Madeleine  16  2000/02/29  女性    会社員
# 3       3124      Amber  16  2000/07/07  女性    管理職
# 4       3390       Leah  16  2000/07/06  女性    公務員
# ...      ...        ...  ..         ...  ..    ...
# 39995   3102      Chloe  67  1950/01/10  女性  エンジニア
# 39996  22998     Hayley  67  1950/01/11  女性    公務員
# 39997  29161       Seth  67  1950/01/10  男性    管理職
# 39998  32860   Madeline  67  1950/01/10  女性     医者
# 39999  37709     Hunter  67  1950/01/11  男性    会社員
#
# [40000 rows x 6 columns]

# %%
df_customer.describe()
# Out:
#                  年齢
# count  40000.000000
# mean      41.016350
# std       13.934283
# min       16.000000
# 25%       29.000000
# 50%       41.000000
# 75%       53.000000
# max       67.000000

# %%
df_customer["年齢セグメント"] = pd.cut(df_customer["年齢"], [10, 20, 30, 40, 50, 60, 70], 
                                labels=["10代", "20代", "30代", "40代", "50代", "60代"], 
                                right=False)
df_customer
# Out:
#         顧客ID         名前  年齢         誕生日  性別     職業 年齢セグメント
# 0       1456      Abbey  16  2000/05/31  女性    ナース     10代
# 1       2424      Ryder  16  2000/05/07  男性    会社員     10代
# 2       2771  Madeleine  16  2000/02/29  女性    会社員     10代
# 3       3124      Amber  16  2000/07/07  女性    管理職     10代
# 4       3390       Leah  16  2000/07/06  女性    公務員     10代
# ...      ...        ...  ..         ...  ..    ...     ...
# 39995   3102      Chloe  67  1950/01/10  女性  エンジニア     60代
# 39996  22998     Hayley  67  1950/01/11  女性    公務員     60代
# 39997  29161       Seth  67  1950/01/10  男性    管理職     60代
# 39998  32860   Madeline  67  1950/01/10  女性     医者     60代
# 39999  37709     Hunter  67  1950/01/11  男性    会社員     60代
#
# [40000 rows x 7 columns]

# %%
df_customer["性別ダミー"] = df_customer["性別"].replace({"男性": 0, "女性": 1})
df_customer
# Out:
# C:\Users\B221228\AppData\Local\Temp\ipykernel_20520\826827518.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_customer["性別ダミー"] = df_customer["性別"].replace({"男性": 0, "女性": 1})
#         顧客ID         名前  年齢         誕生日  性別     職業 年齢セグメント  性別ダミー
# 0       1456      Abbey  16  2000/05/31  女性    ナース     10代      1
# 1       2424      Ryder  16  2000/05/07  男性    会社員     10代      0
# 2       2771  Madeleine  16  2000/02/29  女性    会社員     10代      1
# 3       3124      Amber  16  2000/07/07  女性    管理職     10代      1
# 4       3390       Leah  16  2000/07/06  女性    公務員     10代      1
# ...      ...        ...  ..         ...  ..    ...     ...    ...
# 39995   3102      Chloe  67  1950/01/10  女性  エンジニア     60代      1
# ...

# %%
fpath = os.path.join(DATA_DIR, "演習02_注文明細.xlsx")
df_order = pd.read_excel(fpath)
df_order
# Out:
#        顧客ID  売上金額  販売数量       Date  商品ID         部門      ブランド   製品カテゴリ  \
# 0         1  4.99     1 2014-10-30  1072       デジタル    FunPod      カメラ
# 1         2  4.99     1 2014-12-16  1210        ゲーム    FunPod    ポータブル
# 2         2  4.99     1 2014-12-16  1472  コミュニケーション   BizTech  スマートフォン
# 3         2  3.99     1 2015-01-01   704       電子機器   BizTech   アクセサリー
# 4         3  4.99     1 2015-08-08  1129       デジタル    FunPod      カメラ
# ...     ...   ...   ...        ...   ...        ...       ...      ...
# 7951   3345  4.99     1 2015-03-08  1294       電子機器   BizTech   アクセサリー
# 7952   3345  4.99     1 2015-06-28  1228         TV  HomeView   Plasma
# 7953   3456  3.99     1 2015-06-30   805       電子機器   BizTech    オーディオ
# 7954   4567  3.99     1 2015-06-01   885        ゲーム    FunPod    ポータブル
# 7955  6789a  3.99     1 2015-04-15   926       サービス  HomeView   メンテナンス
#
#                   商品サブカテゴリ   Date_ID
# 0          MPEG4 Camcorder  20141030
# 1             PocketFun ES  20141216
# ...

# %%
df_inner = pd.merge(df_order, df_customer, on="顧客ID", how="inner")
df_inner
# Out:
#       顧客ID  売上金額  販売数量       Date  商品ID         部門      ブランド   製品カテゴリ  \
# 0        1  4.99     1 2014-10-30  1072       デジタル    FunPod      カメラ
# 1        2  4.99     1 2014-12-16  1210        ゲーム    FunPod    ポータブル
# 2        2  4.99     1 2014-12-16  1472  コミュニケーション   BizTech  スマートフォン
# 3        2  3.99     1 2015-01-01   704       電子機器   BizTech   アクセサリー
# 4        3  4.99     1 2015-08-08  1129       デジタル    FunPod      カメラ
# ...    ...   ...   ...        ...   ...        ...       ...      ...
# 7949  3344  3.99     1 2015-04-15   926       サービス  HomeView   メンテナンス
# 7950  3345  4.99     1 2015-03-08  1294       電子機器   BizTech   アクセサリー
# 7951  3345  4.99     1 2015-06-28  1228         TV  HomeView   Plasma
# 7952  3456  3.99     1 2015-06-30   805       電子機器   BizTech    オーディオ
# 7953  4567  3.99     1 2015-06-01   885        ゲーム    FunPod    ポータブル
#
#                   商品サブカテゴリ   Date_ID        名前  年齢         誕生日  性別     職業  \
# ...

# %%
df_outer = pd.merge(df_order, df_customer, on="顧客ID", how="outer")
df_outer
# Out:
#         顧客ID  売上金額  販売数量       Date    商品ID         部門      ブランド   製品カテゴリ  \
# 0          1  4.99   1.0 2014-10-30  1072.0       デジタル    FunPod      カメラ
# 1          2  4.99   1.0 2014-12-16  1210.0        ゲーム    FunPod    ポータブル
# 2          2  4.99   1.0 2014-12-16  1472.0  コミュニケーション   BizTech  スマートフォン
# 3          2  3.99   1.0 2015-01-01   704.0       電子機器   BizTech   アクセサリー
# 4          3  4.99   1.0 2015-08-08  1129.0       デジタル    FunPod      カメラ
# ...      ...   ...   ...        ...     ...        ...       ...      ...
# 44794  39998   NaN   NaN        NaT     NaN        NaN       NaN      NaN
# 44795  39999   NaN   NaN        NaT     NaN        NaN       NaN      NaN
# 44796  40000   NaN   NaN        NaT     NaN        NaN       NaN      NaN
# 44797    51a   NaN   NaN        NaT     NaN        NaN       NaN      NaN
# 44798  6789a  3.99   1.0 2015-04-15   926.0       サービス  HomeView   メンテナンス
#
#                 商品サブカテゴリ     Date_ID         名前    年齢         誕生日   性別     職業  \
# ...

# %%
pd.merge(df_order, df_customer, on="顧客ID", how="outer", indicator=True)
# Out:
#         顧客ID  売上金額  販売数量       Date    商品ID         部門      ブランド   製品カテゴリ  \
# 0          1  4.99   1.0 2014-10-30  1072.0       デジタル    FunPod      カメラ
# 1          2  4.99   1.0 2014-12-16  1210.0        ゲーム    FunPod    ポータブル
# 2          2  4.99   1.0 2014-12-16  1472.0  コミュニケーション   BizTech  スマートフォン
# 3          2  3.99   1.0 2015-01-01   704.0       電子機器   BizTech   アクセサリー
# 4          3  4.99   1.0 2015-08-08  1129.0       デジタル    FunPod      カメラ
# ...      ...   ...   ...        ...     ...        ...       ...      ...
# 44794  39998   NaN   NaN        NaT     NaN        NaN       NaN      NaN
# 44795  39999   NaN   NaN        NaT     NaN        NaN       NaN      NaN
# 44796  40000   NaN   NaN        NaT     NaN        NaN       NaN      NaN
# 44797    51a   NaN   NaN        NaT     NaN        NaN       NaN      NaN
# 44798  6789a  3.99   1.0 2015-04-15   926.0       サービス  HomeView   メンテナンス
#
#                 商品サブカテゴリ     Date_ID         名前    年齢         誕生日   性別     職業  \
# ...

# %%
df_left = pd.merge(df_order, df_customer, on="顧客ID", how="left")
df_left
# Out:
#        顧客ID  売上金額  販売数量       Date  商品ID         部門      ブランド   製品カテゴリ  \
# 0         1  4.99     1 2014-10-30  1072       デジタル    FunPod      カメラ
# 1         2  4.99     1 2014-12-16  1210        ゲーム    FunPod    ポータブル
# 2         2  4.99     1 2014-12-16  1472  コミュニケーション   BizTech  スマートフォン
# 3         2  3.99     1 2015-01-01   704       電子機器   BizTech   アクセサリー
# 4         3  4.99     1 2015-08-08  1129       デジタル    FunPod      カメラ
# ...     ...   ...   ...        ...   ...        ...       ...      ...
# 7951   3345  4.99     1 2015-03-08  1294       電子機器   BizTech   アクセサリー
# 7952   3345  4.99     1 2015-06-28  1228         TV  HomeView   Plasma
# 7953   3456  3.99     1 2015-06-30   805       電子機器   BizTech    オーディオ
# 7954   4567  3.99     1 2015-06-01   885        ゲーム    FunPod    ポータブル
# 7955  6789a  3.99     1 2015-04-15   926       サービス  HomeView   メンテナンス
#
#                   商品サブカテゴリ   Date_ID       名前    年齢         誕生日   性別     職業  \
# ...

# %%
df_left.to_excel(os.path.join(DATA_DIR, "顧客-注文明細結合済み.xlsx"))

# %%
fpath = os.path.join(DATA_DIR, "演習03_マンション価格データ.xlsx")
df_house = pd.read_excel(fpath)
df_house
# Out:
#       ID  Price  Minutes  Age  Area  One room
# 0      1    620        5   26    15         1
# 1      2   3700        3   11    50         0
# 2      3   3700       12   12    55         0
# 3      4   3400        9    9    55         0
# 4      5   1400        2   18    20         1
# ..   ...    ...      ...  ...   ...       ...
# 189  190   3800        6   10    55         0
# 190  191   4800        6   10    65         0
# 191  192   4800        5    6    50         0
# 192  193   1100        4   42    35         0
# 193  194   3400        8   24    60         0
#
# [194 rows x 6 columns]

# %%
df_house.describe()
# Out:
#                ID         Price     Minutes         Age        Area  \
# count  194.000000    194.000000  194.000000  194.000000  194.000000
# mean    97.500000   3762.577320    8.984536   14.984536   53.530928
# std     56.147128   2150.960638    5.412973   11.493398   29.115307
# min      1.000000    500.000000    0.000000    0.000000   10.000000
# 25%     49.250000   2425.000000    5.000000    6.000000   35.000000
# 50%     97.500000   3600.000000    8.000000   11.000000   50.000000
# 75%    145.750000   4900.000000   12.000000   23.750000   70.000000
# max    194.000000  19000.000000   29.000000   43.000000  280.000000
#
#          One room
# count  194.000000
# mean     0.190722
# std      0.393887
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      0.000000
# max      1.000000

# %%
sns.heatmap(df_house.corr(numeric_only=True), annot=True, fmt=".2f", cmap="Blues", )
# Out:
# <Axes: >

# %%
sns.pairplot(df_house)

# %%
# 単回帰分析
from sklearn import linear_model

X = df_house[["Area"]]
y = df_house["Price"]

model = linear_model.LinearRegression()
model.fit(X, y)

display(pd.DataFrame({"Variables": X.columns, "Coefficients": model.coef_}))

print("切片:", model.intercept_)
print("決定係数:", model.score(X, y))
# Out:
#   Variables  Coefficients
# 0      Area     65.412112
# 切片: 261.0062815802021
# 決定係数: 0.7839604754917736

# %%
# モデルの可視化
plt.scatter(X, y)
y_pred = model.predict(X)
plt.plot(X["Area"], y_pred)

# %%
# 残差プロット
plt.scatter(X, y - y_pred)
plt.hlines(y=0, xmin = 0, xmax = 300, color = 'black')

# %%
# 重回帰分析
from sklearn import linear_model

X = df_house[["Minutes", "Age", "One room", "Area"]]
y = df_house["Price"]

model = linear_model.LinearRegression()
model.fit(X, y)

display(pd.DataFrame({"Variables": X.columns, "Coefficients": model.coef_}))

print("切片:", model.intercept_)
print("決定係数:", model.score(X, y))
# Out:
#   Variables  Coefficients
# 0   Minutes    -36.794087
# 1       Age    -61.303933
# 2  One room   -544.814094
# 3      Area     60.141285
# 切片: 1896.255163589296
# 決定係数: 0.8919247376265831

# %%
### モデルの可視化 ###

# Xをモデル式に代入して予測結果を算出
y_pred = model.predict(X)

# 「徒歩分数」の実測値と予測結果をプロット
plt.subplot(2, 2, 1)                               # plt.subplot(行数, 列数, 何番目のプロットか)で複数グラフを同時に描画可能
dataname = 'Minutes'
plt.scatter(X[dataname], y)
# 回帰直線をプロット
plt.plot(X[dataname], y_pred, color = 'orange') # Xと予測結果Y_predをプロット
plt.xlabel(dataname)                               # X軸ラベル


# 「築年数」の実測値と予測結果をプロット
plt.subplot(2, 2, 2)                               # plt.subplot(行数, 列数, 何番目のプロットか)で複数グラフを同時に描画可能
dataname = 'Age'
plt.scatter(X[dataname], y)
# 回帰直線をプロット
plt.plot(X[dataname], y_pred, color = 'orange') # Xと予測結果Y_predをプロット
plt.xlabel(dataname)                               # X軸ラベル


# 「占有面積」の実測値と予測結果をプロット
plt.subplot(2, 2, 3)                               # plt.subplot(行数, 列数, 何番目のプロットか)で複数グラフを同時に描画可能
dataname = 'Area'
plt.scatter(X[dataname], y)
# 回帰直線をプロット
plt.plot(X[dataname], y_pred, color = 'orange') # Xと予測結果Y_predをプロット
plt.xlabel(dataname)                               # X軸ラベル


# 「ワンルーム」の実測値と予測結果をプロット
plt.subplot(2, 2, 4)                               # plt.subplot(行数, 列数, 何番目のプロットか)で複数グラフを同時に描画可能
dataname = 'One room'
plt.scatter(X[dataname], y)
# 回帰直線をプロット
plt.plot(X[dataname], y_pred, color = 'orange') # Xと予測結果Y_predをプロット
plt.xlabel(dataname)                               # X軸ラベル


# グラフ同士が重ならないように設定
plt.tight_layout()                                 
    
# プロット結果を表示
plt.show()

# %%
plt.plot(X[["Area"]], y_pred)

# %%
### 標準化 ###
from sklearn import preprocessing 

X_standard = preprocessing.scale(X)
y_standard = preprocessing.scale(y)

### モデル構築（フィッティング） ###
model.fit(X_standard, y_standard)

# 偏回帰係数の出力
display( pd.DataFrame({"Variables":X.columns, "Coefficients":model.coef_}) )

# 切片の出力
print('切片:', model.intercept_)

# 決定係数の出力
print('決定係数:', model.score(X_standard, y_standard))
# Out:
#   Variables  Coefficients
# 0   Minutes     -0.092594
# 1       Age     -0.327570
# 2  One room     -0.099767
# 3      Area      0.814070
# 切片: -1.4356671786075823e-17
# 決定係数: 0.8919247376265831

# %%
# ニューラルネットワークのライブラリ読み込み
from sklearn.neural_network import MLPRegressor #scikit-learnパッケージ内の ニューラルネットワークのモジュールより、
                                                #多層パーセプトロン (MLP) 回帰のクラスを読込

# ニューラルネットワークモデル構築
model = MLPRegressor( random_state=0, hidden_layer_sizes=(100,))   #インスタンス化（関数を使える状態にする）
            #パラメータの説明：
            # random_state: 乱数のシード値。指定することで再現性を担保
            # hidden_layer_sizes=(100,) は隠れ層1、ノード数100を意味する

model.fit(X_standard, y_standard)  #モデル構築（フィッティング）
# Out:
# MLPRegressor(random_state=0)

# %%
# モデル予測値の出力
Y_pred = model.predict(X_standard)

# 精度の出力
model.score(X_standard, y_standard)
# Out:
# 0.8999892466833119

# %%
df_titanic.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df_titanic["Age"] = df_titanic["Age"].fillna(df_titanic["Age"].median())
df_titanic["Embarked"] = df_titanic["Embarked"].fillna("S")
df_titanic.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %%
### 「Sex」の「male／female」をダミー変数化（0/1） ###
df_titanic['Sex'] = df_titanic['Sex'].replace( {'male':0, 'female':1} ) # Noはただの識別番号のため可視化から除外

### 「Embarked」の「C/Q/S」をダミー変数化（0/1/2） ###
df_titanic['Embarked'] = df_titanic['Embarked'].replace( {'C':0, 'Q':1, 'S':2} ) # Noはただの識別番号のため可視化から除外

df_titanic
# Out:
# C:\Users\B221228\AppData\Local\Temp\ipykernel_20520\3331820682.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_titanic['Sex'] = df_titanic['Sex'].replace( {'male':0, 'female':1} ) # Noはただの識別番号のため可視化から除外
# C:\Users\B221228\AppData\Local\Temp\ipykernel_20520\3331820682.py:5: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_titanic['Embarked'] = df_titanic['Embarked'].replace( {'C':0, 'Q':1, 'S':2} ) # Noはただの識別番号のため可視化から除外
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# ...

# %%
### ロジスティック回帰分析 ###
from sklearn import linear_model # 機械学習パッケージに含まれた回帰分析モジュール"linear_model"を読込

# 説明変数のセット
X = df_titanic[ ['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked'] ]

# 目的変数のセット
Y = df_titanic['Survived']

# ロジスティック回帰モデルを作成
model = linear_model.LogisticRegression()  # インスタンス化（関数を使える状態にする）
model.fit(X, Y)                            # モデル構築（フィッティング）

# 偏回帰係数の出力
display( pd.DataFrame({"Variables":X.columns, "Coefficients":model.coef_.reshape(-1,)}) )
#もしくは
#display( pd.concat( [pd.DataFrame(X.columns, columns=['Variables']), pd.DataFrame(model.coef_.T, columns=['Coefficients'])], axis=1) )

# 切片の出力
print( '切片:', model.intercept_ )

# 正解率の出力（全データのうち、正解した件数の割合）
print( '正解率:', model.score(X, Y) )
# Out:
#   Variables  Coefficients
# 0    Pclass     -1.050955
# 1       Sex      2.630208
# 2       Age     -0.038044
# 3     SibSp     -0.316149
# 4     Parch     -0.085136
# 5      Fare      0.002159
# 6  Embarked     -0.213345
# 切片: [2.43397441]
# 正解率: 0.8002244668911336

# %%
### 実測値と予測結果の比較 ###

Y_pred = model.predict(X)  # モデルに説明変数を入力して、予測結果を出力
results = pd.DataFrame( {'実測値':Y, '予測値':Y_pred}, columns=['実測値', '予測値'] ) # データフレームに実測値、予測結果を格納

display( results ) # 画面出力
# Out:
#      実測値  予測値
# 0      0    0
# 1      1    1
# 2      1    1
# 3      1    1
# 4      0    0
# ..   ...  ...
# 886    0    0
# 887    1    1
# 888    0    0
# 889    1    1
# 890    0    0
#
# [891 rows x 2 columns]

# %%
### 予測結果の確率を出力 ###

probs = model.predict_proba(X) # モデル.predict_proba(説明変数) で モデルに説明変数を入力したときの予測「確率」を抽出
probs = pd.DataFrame(probs)    # データフレーム型に変換
display( probs ) # 画面出力
# Out:
#             0         1
# 0    0.907463  0.092537
# 1    0.082767  0.917233
# 2    0.374586  0.625414
# 3    0.113698  0.886302
# 4    0.921271  0.078729
# ..        ...       ...
# 886  0.749086  0.250914
# 887  0.050764  0.949236
# 888  0.504098  0.495902
# 889  0.387305  0.612695
# 890  0.894061  0.105939
#
# [891 rows x 2 columns]

# %%
### 予測結果と確率の確認 ###
results['確率(Prob)'] = probs[1]     # 参考データとしてresultsのデータフレームにくっつける

display(results)
# Out:
#      実測値  予測値  確率(Prob)
# 0      0    0  0.092537
# 1      1    1  0.917233
# 2      1    1  0.625414
# 3      1    1  0.886302
# 4      0    0  0.078729
# ..   ...  ...       ...
# 886    0    0  0.250914
# 887    1    1  0.949236
# 888    0    0  0.495902
# 889    1    1  0.612695
# 890    0    0  0.105939
#
# [891 rows x 3 columns]

# %%
## 混同行列、各種精度指標の可視化 ###

#ライブラリ読込：モデル評価のためのライブラリ
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score

#各種 精度指標の出力
print('混同行列 (confusion matrix) = \n', confusion_matrix(y_true= Y, y_pred= Y_pred, labels=[1,0]))
print('正解率 (accuracy) = ', accuracy_score(y_true= Y, y_pred= Y_pred))
print('適合率 (precision) = ', precision_score(y_true= Y, y_pred= Y_pred, pos_label=1))
print('再現率 (recall) = ', recall_score(y_true= Y, y_pred= Y_pred, pos_label=1))
print('F値 (f1 score) = ', f1_score(y_true= Y, y_pred= Y_pred, pos_label=1))
# Out:
# 混同行列 (confusion matrix) =
#  [[239 103]
#  [ 75 474]]
# 正解率 (accuracy) =  0.8002244668911336
# 適合率 (precision) =  0.7611464968152867
# 再現率 (recall) =  0.6988304093567251
# F値 (f1 score) =  0.7286585365853658

# %%
import dtreeviz
print(dtreeviz.__version__)
# Out:
# 2.2.2

# %%
import graphviz
print(graphviz.__version__)
# Out:
# 0.20.3

# %%
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier

import dtreeviz

iris = load_iris()
X = iris.data
y = iris.target

clf = DecisionTreeClassifier(max_depth=4)
clf.fit(X, y)

viz_model = dtreeviz.model(clf,
                           X_train=X, y_train=y,
                           feature_names=iris.feature_names,
                           target_name='iris',
                           class_names=iris.target_names)

# v = viz_model.view()     # render as SVG into internal object 
# v.show()                 # pop up window
# v.save("/tmp/iris.svg")  # optionally save as svg

viz_model.view()       # in notebook, displays inline
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~\Desktop\analysis_2\ds_intermediate\.venv\lib\site-packages\graphviz\backend\execute.py:78, in run_check(cmd, input_lines, encoding, quiet, **kwargs)
#      77     else:
# ---> 78         proc = subprocess.run(cmd, **kwargs)
#      79 except OSError as e:
#
# File ~\.pyenv\pyenv-win\versions\3.10.5\lib\subprocess.py:501, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     499     kwargs['stderr'] = PIPE
# --> 501 with Popen(*popenargs, **kwargs) as process:
#     502     try:
#
# ...

# %%
### 決定木分析 ###
from sklearn import tree     # 機械学習パッケージに含まれた決定木分析モジュール"tree"を読込

# 説明変数のセット
X = df_titanic[ ['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked'] ]

# 目的変数のセット
Y = df_titanic['Survived']

# 決定木モデルを作成
model = tree.DecisionTreeClassifier(max_depth=3, criterion = 'gini', random_state=0)  # インスタンス化（関数を使える状態にする）
    # 各種設定パラメータの説明
    # tree.DecisionTreeRegressor(max_depth=3) とすれば、回帰木
    # max_depth: ツリーの最大深さ
    # criterion: データの分割指標を "gini"（ジニ係数） or "entropy" （情報エントロピー）で指定
    # random_state: 乱数のシード値。指定することで再分析時の再現性を担保

    
model.fit(X, Y)                            # モデル構築（フィッティング）
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=0)

# %%
### スマート可視化ツール "dtreeviz" を使った可視化 ###

import dtreeviz # 決定木可視化ライブラリを読み込み

viz_model = dtreeviz.model(model,
               X,                                 # 説明変数
               Y,                                 # 目的変数
               feature_names = X.columns,         # 決定木の分割条件に記載する説明変数名称
               target_name = 'Survive',           # 凡例に記載する目的変数名称
               class_names = ['0:No', '1:Yes'],   # 凡例に記載するクラス名称
              ) 

# 読み込んだ決定木モデルを描画
viz_model.view(
                fontname = 'Yu Gothic',              # 文字化け防止のためのフォント設定（Windows）
#                 fontname='Hiragino Maru Gothic Pro', # for Mac
                label_fontsize = 18,                 # 説明変数の文字サイズ
                ticks_fontsize = 14,                 # 目盛り数字の文字サイズ
                title = '決定木分析結果',               # グラフタイトル
                title_fontsize = 20,                 # グラフタイトルの文字サイズ
                scale = 1.2                          # 拡大率（描画サイズを拡大・縮小）
              )
# Out:
# C:\Users\B221228\Desktop\analysis_2\ds_intermediate\.venv\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~\Desktop\analysis_2\ds_intermediate\.venv\lib\site-packages\graphviz\backend\execute.py:78, in run_check(cmd, input_lines, encoding, quiet, **kwargs)
#      77     else:
# ---> 78         proc = subprocess.run(cmd, **kwargs)
#      79 except OSError as e:
#
# File ~\.pyenv\pyenv-win\versions\3.10.5\lib\subprocess.py:501, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     499     kwargs['stderr'] = PIPE
# --> 501 with Popen(*popenargs, **kwargs) as process:
#     502     try:
#
# ...

# %%
fpath = os.path.join(DATA_DIR, "演習05_自動車メーカー評価.xlsx")
df_car = pd.read_excel(fpath)
df_car
# Out:
#          自動車メーカー    センスがよい      格調高い      若々しい    信頼感のある    親しみやすい      先進的な  \
# 0         TOYOTA  4.142857  4.428571  4.035714  6.142857  5.571429  5.392857
# 1         NISSAN  4.928571  3.714286  4.857143  5.107143  5.571429  5.071429
# 2          HONDA  4.821429  3.678571  5.821429  5.035714  5.428571  5.535714
# 3           FORD  3.500000  4.178571  3.428571  3.785714  3.035714  3.250000
# 4  MERCEDES－BENZ  4.535714  6.428571  2.928571  5.750000  2.607143  4.285714
# 5            BMW  5.285714  5.678571  3.892857  5.285714  3.071429  4.250000
#
#    技術が優れている      独創的な   スポーティーな    安心感のある
# 0  6.000000  4.750000  4.035714  5.928571
# 1  5.214286  4.678571  4.750000  5.000000
# 2  5.714286  5.321429  5.642857  4.750000
# 3  3.785714  4.178571  3.892857  3.607143
# 4  5.428571  4.500000  3.571429  5.714286
# 5  5.142857  4.464286  4.607143  5.357143

# %%
df_car.describe()
# Out:
#          センスがよい      格調高い      若々しい    信頼感のある    親しみやすい      先進的な  技術が優れている  \
# count  6.000000  6.000000  6.000000  6.000000  6.000000  6.000000  6.000000
# mean   4.535714  4.684524  4.160714  5.184524  4.214286  4.630952  5.214286
# std    0.636476  1.122910  1.037744  0.804140  1.444730  0.867693  0.769309
# min    3.500000  3.678571  2.928571  3.785714  2.607143  3.250000  3.785714
# 25%    4.241071  3.830357  3.544643  5.053571  3.044643  4.258929  5.160714
# 50%    4.678571  4.303571  3.964286  5.196429  4.250000  4.678571  5.321429
# 75%    4.901786  5.366071  4.651786  5.633929  5.535714  5.312500  5.642857
# max    5.285714  6.428571  5.821429  6.142857  5.571429  5.535714  6.000000
#
#            独創的な   スポーティーな    安心感のある
# count  6.000000  6.000000  6.000000
# mean   4.648810  4.416667  5.059524
# std    0.384931  0.746306  0.834421
# min    4.178571  3.571429  3.607143
# 25%    4.473214  3.928571  4.812500
# 50%    4.589286  4.321429  5.178571
# ...

# %%
df_car.isna().sum()
# Out:
# 自動車メーカー     0
# センスがよい      0
# 格調高い        0
# 若々しい        0
# 信頼感のある      0
# 親しみやすい      0
# 先進的な        0
# 技術が優れている    0
# 独創的な        0
# スポーティーな     0
# 安心感のある      0
# dtype: int64

# %%
from sklearn.cluster import KMeans # 機械学習パッケージに含まれたKMeansモジュール"KMeans"を読込

# 説明変数のセット
X = df_car.drop(columns=['自動車メーカー'])  #「自動車メーカー」のカラムを除外した全変数を説明変数にセット

# もしくは、下記のように明示的に説明変数を指定しても可
# X = df[ ['センスがよい', '格調高い', '若々しい', '信頼感のある', '親しみやすい', '先進的な',
#        '技術が優れている', '独創的な', 'スポーティーな', '安心感のある'] ]
#
# X = df.loc[:,'センスがよい':'安心感のある']


# クラスタ数の設定
n = 3

# クラスタリング
model = KMeans( n_clusters=n, random_state=0 )  #クラスタリングの実行準備
                                                # オプションの説明：
                                                # n_clustersでクラスタ数指定
                                                # random_state=数値固定 でモデルの再現性を保持（乱数のシードを固定）
                                                # init='k-means++' or 'random' で初期クラスタ中心の配置方法を指定。defaultは'k-means++'
model.fit(X) #Xを説明変数としてクラスタリング実行
# Out:
# KMeans(n_clusters=3, random_state=0)

# %%
### 所属クラスタ、重心座標の出力 ###
print(model.labels_) # 各データ点が所属するクラスタ
print(model.cluster_centers_) # 各クラスタの重心座標
# Out:
# [1 1 1 0 2 2]
# [[3.5        4.17857143 3.42857143 3.78571429 3.03571429 3.25
#   3.78571429 4.17857143 3.89285714 3.60714286]
#  [4.63095238 3.94047619 4.9047619  5.42857143 5.52380952 5.33333333
#   5.64285714 4.91666667 4.80952381 5.22619048]
#  [4.91071429 6.05357143 3.41071429 5.51785714 2.83928571 4.26785714
#   5.28571429 4.48214286 4.08928571 5.53571429]]

# %%
### 元のdataframeにクラスタ番号を追加 ###
df_car['cluster'] = model.labels_
df_car
# Out:
#          自動車メーカー    センスがよい      格調高い      若々しい    信頼感のある    親しみやすい      先進的な  \
# 0         TOYOTA  4.142857  4.428571  4.035714  6.142857  5.571429  5.392857
# 1         NISSAN  4.928571  3.714286  4.857143  5.107143  5.571429  5.071429
# 2          HONDA  4.821429  3.678571  5.821429  5.035714  5.428571  5.535714
# 3           FORD  3.500000  4.178571  3.428571  3.785714  3.035714  3.250000
# 4  MERCEDES－BENZ  4.535714  6.428571  2.928571  5.750000  2.607143  4.285714
# 5            BMW  5.285714  5.678571  3.892857  5.285714  3.071429  4.250000
#
#    技術が優れている      独創的な   スポーティーな    安心感のある  cluster
# 0  6.000000  4.750000  4.035714  5.928571        1
# 1  5.214286  4.678571  4.750000  5.000000        1
# 2  5.714286  5.321429  5.642857  4.750000        1
# 3  3.785714  4.178571  3.892857  3.607143        0
# 4  5.428571  4.500000  3.571429  5.714286        2
# 5  5.142857  4.464286  4.607143  5.357143        2

# %%
# 複数を並べて表示するために、subplotを定義
fig, axes = plt.subplots(3, 4, figsize=(20,10))

# 数値データ（アンケートデータ）のみ抽出（自動車メーカー名とクラスタ番号を除外）
df_num = df_car.drop(columns=['自動車メーカー','cluster'])

# カラムごとにループを回して、クラスタごとの箱ひげ図を描画
for i, col in enumerate( df_num.columns ):
    j, k = divmod(i, 4) #描くグラフ位置を指定（横方向のグラフ個数=4で割った商と余り）
    sns.boxplot(x='cluster', y=col, data=df_car, ax=axes[j,k]) #該当するカラムの箱ひげ図を指定の位置に描画
    
#　グラフが重ならないように調整
plt.tight_layout()

# %%
### 散布図行列でクラスタごとに色分けして可視化 ###
sns.pairplot(df_car.drop(columns=['自動車メーカー']), hue='cluster')

# %%
### 特定の2変数で、クラスタごとに色分けして可視化＋クラスタ重心の可視化 ###

# 特定の2変数を選択
xcol = '親しみやすい'
ycol = '格調高い'

# 特定の2変数でクラスタごとに色分け可視化
sns.scatterplot( data=df_car, x=xcol, y=ycol, hue='cluster', palette=sns.color_palette(n_colors=3)  )
    #hue: 色分け対象
    #palette: 色パターン
    #クラスタごとにマーカー形状も変えたい場合は、style=df['cluster'] をオプションに加える

# クラスタ重心 (mode.cluster_centers_) の可視化
# ※model.cluster_centers_[:,0]で0番目の説明変数の重心座標
sns.scatterplot( x=model.cluster_centers_[:,1], y=model.cluster_centers_[:,2], marker='*', s=300, color='purple' ) 

# 散布図上に、自動車メーカーの名前をプロット
for i, company in enumerate(df_car['自動車メーカー']):
    plt.annotate(company, (df_car[xcol].values[i], df_car[ycol].values[i]) )
